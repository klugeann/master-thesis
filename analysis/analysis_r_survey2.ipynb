# %%
library(openxlsx)

# %%
source("process/process.R")
# Out:
# ********************* PROCESS for R Version 4.3.1 *********************
#
#            Written by Andrew F. Hayes, Ph.D.  www.afhayes.com
#    Documentation available in Hayes (2022). www.guilford.com/p/hayes3
#
# ***********************************************************************
#
# PROCESS is now ready for use.
# Copyright 2020-2023 by Andrew F. Hayes ALL RIGHTS RESERVED
# Workshop schedule at http://haskayne.ucalgary.ca/CCRAM

# %%
raw_df <- read.csv("../results/survey2_normal_gpt4.1mini_v1.csv", check.names = FALSE)

# %%
short_col_df <- raw_df
names(short_col_df) <- substr(names(raw_df), 1, 3)

# %%
df <- short_col_df[-1, ]

to_number_if_number <- function(s) {
  if (grepl("^[0-9]+$", s)) {
    as.integer(s)
  } else {
    s
  }
}

for (i in 1:38) {
  col_name <- sprintf("%03d", i)
  df[[col_name]] <- sapply(df[[col_name]], function(x) {
    val <- sub("^([a-zA-Z0-9]+).*", "\\1", x)
    to_number_if_number(val)
  })
}

df
# Out:
#      Tri    Sce                    001 002 003 004 005 006 007 008 ⋯ 029 030
# 2    0-01   Disadvantaged Customer a   42  e   g   f   c   c   g   ⋯ 6   5
# 3    0-02   Same Price                                             ⋯ 6   5
# 4    0-03   Favored Customer                                       ⋯ 6   5
# 5    1-01   Same Price             b   57  e   b   c   c   c   d   ⋯ 6   5
# 6    1-02   Disadvantaged Customer                                 ⋯ 6   5
# 7    1-03   Favored Customer                                       ⋯ 6   5
# 8    10-01  Favored Customer       b   57  a   a   c   b   c   d   ⋯ 6   5
# 9    10-02  Same Price                                             ⋯ 6   5
# 10   10-03  Disadvantaged Customer                                 ⋯ 6   6
# 11   100-01 Same Price             a   57  c   a   d   c   c   e   ⋯ 6   5
# 12   100-02 Favored Customer                                       ⋯ 6   5
# 13   100-03 Disadvantaged Customer                                 ⋯ 6   5
# 14   101-01 Same Price             a   47  e   a   c   c   c   d   ⋯ 7   6
# 15   101-02 Favored Customer                                       ⋯ 7   6
# 16   101-03 Disadvantaged Customer                                 ⋯ 7   6
# 17   102-01 Disadvantaged Customer a   42  d   a   a   c   c   d   ⋯ 6   5
# 18   102-02 Same Price                                             ⋯ 6   5
# 19   102-03 Favored Customer                                       ⋯ 6   5
# 20   103-01 Disadvantaged Customer b   47  b   a   e   c   c   e   ⋯ 6   5
# 21   103-02 Same Price                                             ⋯ 6   5
# 22   103-03 Favored Customer                                       ⋯ 6   5
# 23   104-01 Favored Customer       a   57  e   b   e   c   c   e   ⋯ 6   5
# 24   104-02 Same Price                                             ⋯ 6   5
# 25   104-03 Disadvantaged Customer                                 ⋯ 6   5
# 26   105-01 Disadvantaged Customer a   47  a   a   d   c   c   e   ⋯ 6   5
# 27   105-02 Same Price                                             ⋯ 6   5
# 28   105-03 Favored Customer                                       ⋯ 6   5
# 29   106-01 Favored Customer       b   47  d   a   a   c   c   d   ⋯ 6   5
# 30   106-02 Same Price                                             ⋯ 6   5
# 31   106-03 Disadvantaged Customer                                 ⋯ 6   5
# ⋮    ⋮      ⋮                      ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋱ ⋮   ⋮
# 1292 90-01  Favored Customer       b   47  e   a   d   c   c   e   ⋯ 6   5
# 1293 90-02  Same Price                                             ⋯ 6   5
# 1294 90-03  Disadvantaged Customer                                 ⋯ 6   5
# 1295 91-01  Disadvantaged Customer a   57  d   a   c   c   c   e   ⋯ 6   5
# 1296 91-02  Same Price                                             ⋯ 6   5
# 1297 91-03  Favored Customer                                       ⋯ 6   5
# 1298 92-01  Favored Customer       b   57  e   b   e   c   c   f   ⋯ 6   5
# 1299 92-02  Disadvantaged Customer                                 ⋯ 6   5
# 1300 92-03  Same Price                                             ⋯ 6   5
# 1301 93-01  Same Price             a   57  c   b   d   c   c   d   ⋯ 6   5
# 1302 93-02  Favored Customer                                       ⋯ 6   5
# 1303 93-03  Disadvantaged Customer                                 ⋯ 6   5
# 1304 94-01  Favored Customer       a   47  d   a   c   c   c   d   ⋯ 6   5
# 1305 94-02  Disadvantaged Customer                                 ⋯ 6   5
# 1306 94-03  Same Price                                             ⋯ 6   5
# 1307 95-01  Disadvantaged Customer b   57  e   g   c   c   c   d   ⋯ 6   5
# 1308 95-02  Favored Customer                                       ⋯ 6   5
# 1309 95-03  Same Price                                             ⋯ 6   5
# 1310 96-01  Favored Customer       b   47  a   a   d   c   c   e   ⋯ 6   5
# 1311 96-02  Same Price                                             ⋯ 6   5
# 1312 96-03  Disadvantaged Customer                                 ⋯ 6   5
# 1313 97-01  Favored Customer       b   47  b   a   d   c   c   d   ⋯ 6   5
# 1314 97-02  Same Price                                             ⋯ 6   5
# 1315 97-03  Disadvantaged Customer                                 ⋯ 6   5
# 1316 98-01  Disadvantaged Customer b   57  b   b   c   c   c   d   ⋯ 6   5
# 1317 98-02  Same Price                                             ⋯ 6   5
# 1318 98-03  Favored Customer                                       ⋯ 6   5
# 1319 99-01  Same Price             a   57  e   f   e   c   c   e   ⋯ 6   5
# 1320 99-02  Favored Customer                                       ⋯ 6   5
# 1321 99-03  Disadvantaged Customer                                 ⋯ 6   5
#      031 032 033 034 035 036 037 038
# 2    6   5   6   4   6   a   7   6
# 3    6   5   6   4   6   b   7   6
# 4    6   5   6   4   6   c   7   6
# 5    6   5   5   4   6   b   7   6
# 6    6   5   5   4   6   a   7   6
# 7    6   5   5   4   6   c   7   6
# 8    6   5   6   4   6   c   7   6
# 9    6   5   6   4   6   b   7   6
# 10   6   5   6   5   6   a   7   6
# 11   6   5   5   4   6   b   7   6
# 12   6   5   5   4   6   c   7   6
# 13   6   5   5   4   6   a   7   6
# 14   7   6   6   5   7   b   7   6
# 15   7   5   6   5   7   c   7   6
# 16   7   5   6   5   7   a   7   6
# 17   6   5   5   4   6   a   7   6
# 18   6   5   5   4   6   b   7   6
# 19   6   5   5   4   6   c   7   6
# 20   6   5   6   4   6   a   7   6
# 21   6   5   6   4   6   b   7   6
# 22   6   5   6   4   6   c   7   6
# 23   6   5   6   4   6   c   7   6
# 24   6   5   6   4   6   b   7   6
# 25   6   5   6   4   6   a   7   6
# 26   6   5   5   4   6   a   7   6
# 27   6   5   5   4   6   b   7   6
# 28   6   5   5   4   6   c   7   6
# 29   6   5   6   4   6   c   7   6
# 30   6   5   6   4   6   b   7   6
# 31   6   5   6   4   6   a   7   6
# ⋮    ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮
# 1292 6   5   6   4   6   c   7   6
# 1293 6   5   6   4   6   b   7   6
# 1294 6   5   6   4   6   a   7   6
# 1295 6   5   5   4   6   a   7   6
# 1296 6   5   5   4   6   b   7   6
# 1297 6   5   5   4   6   c   7   6
# 1298 6   5   6   4   6   c   7   6
# 1299 6   5   6   4   6   a   7   6
# 1300 6   5   6   4   6   b   7   6
# 1301 6   5   6   5   6   b   7   6
# 1302 6   5   5   5   6   c   7   6
# 1303 6   5   5   5   6   a   7   6
# 1304 6   5   5   4   6   c   7   6
# 1305 6   5   5   4   6   a   7   6
# 1306 6   5   5   4   6   b   7   6
# 1307 6   5   5   4   6   a   6   6
# 1308 6   5   5   4   6   c   6   6
# 1309 6   5   5   4   6   b   7   6
# 1310 6   5   5   4   6   c   7   6
# 1311 6   5   5   4   6   b   7   6
# 1312 6   5   5   4   6   a   7   6
# 1313 6   5   5   4   6   c   7   6
# 1314 6   5   5   4   6   b   7   6
# 1315 6   5   5   4   6   a   7   6
# 1316 6   5   5   4   6   a   7   6
# 1317 6   5   5   4   6   b   7   6
# 1318 6   5   5   4   6   c   7   6
# 1319 7   5   5   4   7   b   7   7
# 1320 7   4   4   4   6   c   7   6
# 1321 7   5   5   4   7   a   7   6

# %%
first_row <- as.data.frame(t(short_col_df[1, , drop = FALSE]), stringsAsFactors = FALSE)
colnames(first_row) <- "groups"

column_group_index <- function(group_name) {
  matching <- first_row$groups == group_name
  cols = rownames(first_row)[matching]
  valid_cols <- intersect(cols, names(df))
  return(valid_cols)
}

# %%
library(dplyr)

# Fill demographics

columns = do.call(c, list(
    column_group_index("00 Demographics"),
    column_group_index("11 Daily Internet Usage"),
    column_group_index("12 Frequency of Online Purchases"),
    column_group_index("13 Money Spent for Online Purchases"),
    column_group_index("14 Social Media Usage")
))

cat("Cols:", columns)

df <- df %>%
  mutate(trial = (row_number() - 1) %/% 3) %>%
  group_by(trial) %>%
  mutate(across(all_of(columns), ~ first(.))) %>%
  ungroup() %>%
  select(-trial)

df$SceIdx  <- as.integer(sub(".*-",  "", df$Tri))
df$Tri <- as.integer(sub("-.*", "", df$Tri))

df
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# Cols: 001 002 003 004 005 006 007 008 009
#      Tri Sce                    001 002 003 004 005 006 007 008 ⋯ 030 031 032
# 1      0 Disadvantaged Customer a   42  e   g   f   c   c   g   ⋯ 5   6   5
# 2      0 Same Price             a   42  e   g   f   c   c   g   ⋯ 5   6   5
# 3      0 Favored Customer       a   42  e   g   f   c   c   g   ⋯ 5   6   5
# 4      1 Same Price             b   57  e   b   c   c   c   d   ⋯ 5   6   5
# 5      1 Disadvantaged Customer b   57  e   b   c   c   c   d   ⋯ 5   6   5
# 6      1 Favored Customer       b   57  e   b   c   c   c   d   ⋯ 5   6   5
# 7     10 Favored Customer       b   57  a   a   c   b   c   d   ⋯ 5   6   5
# 8     10 Same Price             b   57  a   a   c   b   c   d   ⋯ 5   6   5
# 9     10 Disadvantaged Customer b   57  a   a   c   b   c   d   ⋯ 6   6   5
# 10   100 Same Price             a   57  c   a   d   c   c   e   ⋯ 5   6   5
# 11   100 Favored Customer       a   57  c   a   d   c   c   e   ⋯ 5   6   5
# 12   100 Disadvantaged Customer a   57  c   a   d   c   c   e   ⋯ 5   6   5
# 13   101 Same Price             a   47  e   a   c   c   c   d   ⋯ 6   7   6
# 14   101 Favored Customer       a   47  e   a   c   c   c   d   ⋯ 6   7   5
# 15   101 Disadvantaged Customer a   47  e   a   c   c   c   d   ⋯ 6   7   5
# 16   102 Disadvantaged Customer a   42  d   a   a   c   c   d   ⋯ 5   6   5
# 17   102 Same Price             a   42  d   a   a   c   c   d   ⋯ 5   6   5
# 18   102 Favored Customer       a   42  d   a   a   c   c   d   ⋯ 5   6   5
# 19   103 Disadvantaged Customer b   47  b   a   e   c   c   e   ⋯ 5   6   5
# 20   103 Same Price             b   47  b   a   e   c   c   e   ⋯ 5   6   5
# 21   103 Favored Customer       b   47  b   a   e   c   c   e   ⋯ 5   6   5
# 22   104 Favored Customer       a   57  e   b   e   c   c   e   ⋯ 5   6   5
# 23   104 Same Price             a   57  e   b   e   c   c   e   ⋯ 5   6   5
# 24   104 Disadvantaged Customer a   57  e   b   e   c   c   e   ⋯ 5   6   5
# 25   105 Disadvantaged Customer a   47  a   a   d   c   c   e   ⋯ 5   6   5
# 26   105 Same Price             a   47  a   a   d   c   c   e   ⋯ 5   6   5
# 27   105 Favored Customer       a   47  a   a   d   c   c   e   ⋯ 5   6   5
# 28   106 Favored Customer       b   47  d   a   a   c   c   d   ⋯ 5   6   5
# 29   106 Same Price             b   47  d   a   a   c   c   d   ⋯ 5   6   5
# 30   106 Disadvantaged Customer b   47  d   a   a   c   c   d   ⋯ 5   6   5
# ⋮    ⋮   ⋮                      ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋱ ⋮   ⋮   ⋮
# 1291 90  Favored Customer       b   47  e   a   d   c   c   e   ⋯ 5   6   5
# 1292 90  Same Price             b   47  e   a   d   c   c   e   ⋯ 5   6   5
# 1293 90  Disadvantaged Customer b   47  e   a   d   c   c   e   ⋯ 5   6   5
# 1294 91  Disadvantaged Customer a   57  d   a   c   c   c   e   ⋯ 5   6   5
# 1295 91  Same Price             a   57  d   a   c   c   c   e   ⋯ 5   6   5
# 1296 91  Favored Customer       a   57  d   a   c   c   c   e   ⋯ 5   6   5
# 1297 92  Favored Customer       b   57  e   b   e   c   c   f   ⋯ 5   6   5
# 1298 92  Disadvantaged Customer b   57  e   b   e   c   c   f   ⋯ 5   6   5
# 1299 92  Same Price             b   57  e   b   e   c   c   f   ⋯ 5   6   5
# 1300 93  Same Price             a   57  c   b   d   c   c   d   ⋯ 5   6   5
# 1301 93  Favored Customer       a   57  c   b   d   c   c   d   ⋯ 5   6   5
# 1302 93  Disadvantaged Customer a   57  c   b   d   c   c   d   ⋯ 5   6   5
# 1303 94  Favored Customer       a   47  d   a   c   c   c   d   ⋯ 5   6   5
# 1304 94  Disadvantaged Customer a   47  d   a   c   c   c   d   ⋯ 5   6   5
# 1305 94  Same Price             a   47  d   a   c   c   c   d   ⋯ 5   6   5
# 1306 95  Disadvantaged Customer b   57  e   g   c   c   c   d   ⋯ 5   6   5
# 1307 95  Favored Customer       b   57  e   g   c   c   c   d   ⋯ 5   6   5
# 1308 95  Same Price             b   57  e   g   c   c   c   d   ⋯ 5   6   5
# 1309 96  Favored Customer       b   47  a   a   d   c   c   e   ⋯ 5   6   5
# 1310 96  Same Price             b   47  a   a   d   c   c   e   ⋯ 5   6   5
# 1311 96  Disadvantaged Customer b   47  a   a   d   c   c   e   ⋯ 5   6   5
# 1312 97  Favored Customer       b   47  b   a   d   c   c   d   ⋯ 5   6   5
# 1313 97  Same Price             b   47  b   a   d   c   c   d   ⋯ 5   6   5
# 1314 97  Disadvantaged Customer b   47  b   a   d   c   c   d   ⋯ 5   6   5
# 1315 98  Disadvantaged Customer b   57  b   b   c   c   c   d   ⋯ 5   6   5
# 1316 98  Same Price             b   57  b   b   c   c   c   d   ⋯ 5   6   5
# 1317 98  Favored Customer       b   57  b   b   c   c   c   d   ⋯ 5   6   5
# 1318 99  Same Price             a   57  e   f   e   c   c   e   ⋯ 5   7   5
# 1319 99  Favored Customer       a   57  e   f   e   c   c   e   ⋯ 5   7   4
# 1320 99  Disadvantaged Customer a   57  e   f   e   c   c   e   ⋯ 5   7   5
#      033 034 035 036 037 038 SceIdx
# 1    6   4   6   a   7   6   1
# 2    6   4   6   b   7   6   2
# 3    6   4   6   c   7   6   3
# 4    5   4   6   b   7   6   1
# 5    5   4   6   a   7   6   2
# 6    5   4   6   c   7   6   3
# 7    6   4   6   c   7   6   1
# 8    6   4   6   b   7   6   2
# 9    6   5   6   a   7   6   3
# 10   5   4   6   b   7   6   1
# 11   5   4   6   c   7   6   2
# 12   5   4   6   a   7   6   3
# 13   6   5   7   b   7   6   1
# 14   6   5   7   c   7   6   2
# 15   6   5   7   a   7   6   3
# 16   5   4   6   a   7   6   1
# 17   5   4   6   b   7   6   2
# 18   5   4   6   c   7   6   3
# 19   6   4   6   a   7   6   1
# 20   6   4   6   b   7   6   2
# 21   6   4   6   c   7   6   3
# 22   6   4   6   c   7   6   1
# 23   6   4   6   b   7   6   2
# 24   6   4   6   a   7   6   3
# 25   5   4   6   a   7   6   1
# 26   5   4   6   b   7   6   2
# 27   5   4   6   c   7   6   3
# 28   6   4   6   c   7   6   1
# 29   6   4   6   b   7   6   2
# 30   6   4   6   a   7   6   3
# ⋮    ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮
# 1291 6   4   6   c   7   6   1
# 1292 6   4   6   b   7   6   2
# 1293 6   4   6   a   7   6   3
# 1294 5   4   6   a   7   6   1
# 1295 5   4   6   b   7   6   2
# 1296 5   4   6   c   7   6   3
# 1297 6   4   6   c   7   6   1
# 1298 6   4   6   a   7   6   2
# 1299 6   4   6   b   7   6   3
# 1300 6   5   6   b   7   6   1
# 1301 5   5   6   c   7   6   2
# 1302 5   5   6   a   7   6   3
# 1303 5   4   6   c   7   6   1
# 1304 5   4   6   a   7   6   2
# 1305 5   4   6   b   7   6   3
# 1306 5   4   6   a   6   6   1
# 1307 5   4   6   c   6   6   2
# 1308 5   4   6   b   7   6   3
# 1309 5   4   6   c   7   6   1
# 1310 5   4   6   b   7   6   2
# 1311 5   4   6   a   7   6   3
# 1312 5   4   6   c   7   6   1
# 1313 5   4   6   b   7   6   2
# 1314 5   4   6   a   7   6   3
# 1315 5   4   6   a   7   6   1
# 1316 5   4   6   b   7   6   2
# 1317 5   4   6   c   7   6   3
# 1318 5   4   7   b   7   7   1
# 1319 4   4   6   c   7   6   2
# 1320 5   4   7   a   7   6   3

# %%
df$price_fairness <- rowMeans(sapply(column_group_index("01 Distributive Price Fairness Perception"), function(col) as.integer(df[[col]])))
df$purchase_intention <- rowMeans(sapply(column_group_index("03 Purchase Intention"), function(col) as.integer(df[[col]])))
df$future_search_intention <- rowMeans(sapply(column_group_index("04 Future Search Intention"), function(col) as.integer(df[[col]])))
df$product_involvement <- rowMeans(sapply(column_group_index("08 Product Involvement"), function(col) as.integer(df[[col]])))
df$perceived_information <- rowMeans(sapply(column_group_index("18 Perceived Information Sensitivity"), function(col) as.integer(df[[col]])))
df$willingness_reveal <- rowMeans(sapply(column_group_index("19 Willingness to Reveal Information"), function(col) as.integer(df[[col]])))
df
# Out:
#      Tri Sce                    001 002 003 004 005 006 007 008 ⋯ 036 037 038
# 1      0 Disadvantaged Customer a   42  e   g   f   c   c   g   ⋯ a   7   6
# 2      0 Same Price             a   42  e   g   f   c   c   g   ⋯ b   7   6
# 3      0 Favored Customer       a   42  e   g   f   c   c   g   ⋯ c   7   6
# 4      1 Same Price             b   57  e   b   c   c   c   d   ⋯ b   7   6
# 5      1 Disadvantaged Customer b   57  e   b   c   c   c   d   ⋯ a   7   6
# 6      1 Favored Customer       b   57  e   b   c   c   c   d   ⋯ c   7   6
# 7     10 Favored Customer       b   57  a   a   c   b   c   d   ⋯ c   7   6
# 8     10 Same Price             b   57  a   a   c   b   c   d   ⋯ b   7   6
# 9     10 Disadvantaged Customer b   57  a   a   c   b   c   d   ⋯ a   7   6
# 10   100 Same Price             a   57  c   a   d   c   c   e   ⋯ b   7   6
# 11   100 Favored Customer       a   57  c   a   d   c   c   e   ⋯ c   7   6
# 12   100 Disadvantaged Customer a   57  c   a   d   c   c   e   ⋯ a   7   6
# 13   101 Same Price             a   47  e   a   c   c   c   d   ⋯ b   7   6
# 14   101 Favored Customer       a   47  e   a   c   c   c   d   ⋯ c   7   6
# 15   101 Disadvantaged Customer a   47  e   a   c   c   c   d   ⋯ a   7   6
# 16   102 Disadvantaged Customer a   42  d   a   a   c   c   d   ⋯ a   7   6
# 17   102 Same Price             a   42  d   a   a   c   c   d   ⋯ b   7   6
# 18   102 Favored Customer       a   42  d   a   a   c   c   d   ⋯ c   7   6
# 19   103 Disadvantaged Customer b   47  b   a   e   c   c   e   ⋯ a   7   6
# 20   103 Same Price             b   47  b   a   e   c   c   e   ⋯ b   7   6
# 21   103 Favored Customer       b   47  b   a   e   c   c   e   ⋯ c   7   6
# 22   104 Favored Customer       a   57  e   b   e   c   c   e   ⋯ c   7   6
# 23   104 Same Price             a   57  e   b   e   c   c   e   ⋯ b   7   6
# 24   104 Disadvantaged Customer a   57  e   b   e   c   c   e   ⋯ a   7   6
# 25   105 Disadvantaged Customer a   47  a   a   d   c   c   e   ⋯ a   7   6
# 26   105 Same Price             a   47  a   a   d   c   c   e   ⋯ b   7   6
# 27   105 Favored Customer       a   47  a   a   d   c   c   e   ⋯ c   7   6
# 28   106 Favored Customer       b   47  d   a   a   c   c   d   ⋯ c   7   6
# 29   106 Same Price             b   47  d   a   a   c   c   d   ⋯ b   7   6
# 30   106 Disadvantaged Customer b   47  d   a   a   c   c   d   ⋯ a   7   6
# ⋮    ⋮   ⋮                      ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋱ ⋮   ⋮   ⋮
# 1291 90  Favored Customer       b   47  e   a   d   c   c   e   ⋯ c   7   6
# 1292 90  Same Price             b   47  e   a   d   c   c   e   ⋯ b   7   6
# 1293 90  Disadvantaged Customer b   47  e   a   d   c   c   e   ⋯ a   7   6
# 1294 91  Disadvantaged Customer a   57  d   a   c   c   c   e   ⋯ a   7   6
# 1295 91  Same Price             a   57  d   a   c   c   c   e   ⋯ b   7   6
# 1296 91  Favored Customer       a   57  d   a   c   c   c   e   ⋯ c   7   6
# 1297 92  Favored Customer       b   57  e   b   e   c   c   f   ⋯ c   7   6
# 1298 92  Disadvantaged Customer b   57  e   b   e   c   c   f   ⋯ a   7   6
# 1299 92  Same Price             b   57  e   b   e   c   c   f   ⋯ b   7   6
# 1300 93  Same Price             a   57  c   b   d   c   c   d   ⋯ b   7   6
# 1301 93  Favored Customer       a   57  c   b   d   c   c   d   ⋯ c   7   6
# 1302 93  Disadvantaged Customer a   57  c   b   d   c   c   d   ⋯ a   7   6
# 1303 94  Favored Customer       a   47  d   a   c   c   c   d   ⋯ c   7   6
# 1304 94  Disadvantaged Customer a   47  d   a   c   c   c   d   ⋯ a   7   6
# 1305 94  Same Price             a   47  d   a   c   c   c   d   ⋯ b   7   6
# 1306 95  Disadvantaged Customer b   57  e   g   c   c   c   d   ⋯ a   6   6
# 1307 95  Favored Customer       b   57  e   g   c   c   c   d   ⋯ c   6   6
# 1308 95  Same Price             b   57  e   g   c   c   c   d   ⋯ b   7   6
# 1309 96  Favored Customer       b   47  a   a   d   c   c   e   ⋯ c   7   6
# 1310 96  Same Price             b   47  a   a   d   c   c   e   ⋯ b   7   6
# 1311 96  Disadvantaged Customer b   47  a   a   d   c   c   e   ⋯ a   7   6
# 1312 97  Favored Customer       b   47  b   a   d   c   c   d   ⋯ c   7   6
# 1313 97  Same Price             b   47  b   a   d   c   c   d   ⋯ b   7   6
# 1314 97  Disadvantaged Customer b   47  b   a   d   c   c   d   ⋯ a   7   6
# 1315 98  Disadvantaged Customer b   57  b   b   c   c   c   d   ⋯ a   7   6
# 1316 98  Same Price             b   57  b   b   c   c   c   d   ⋯ b   7   6
# 1317 98  Favored Customer       b   57  b   b   c   c   c   d   ⋯ c   7   6
# 1318 99  Same Price             a   57  e   f   e   c   c   e   ⋯ b   7   7
# 1319 99  Favored Customer       a   57  e   f   e   c   c   e   ⋯ c   7   6
# 1320 99  Disadvantaged Customer a   57  e   f   e   c   c   e   ⋯ a   7   6
#      SceIdx price_fairness purchase_intention future_search_intention
# 1    1      6.000000       5                  7.000000
# 2    2      6.000000       6                  6.000000
# 3    3      3.000000       2                  7.000000
# 4    1      7.000000       6                  5.333333
# 5    2      4.333333       4                  6.333333
# 6    3      3.000000       3                  7.000000
# 7    1      2.333333       3                  7.000000
# 8    2      7.000000       6                  5.000000
# 9    3      7.000000       6                  6.000000
# 10   1      7.000000       6                  7.000000
# 11   2      1.000000       2                  7.000000
# 12   3      7.000000       6                  6.000000
# 13   1      7.000000       7                  6.333333
# 14   2      2.000000       2                  7.000000
# 15   3      6.000000       6                  6.333333
# 16   1      5.333333       6                  6.666667
# 17   2      6.000000       6                  5.666667
# 18   3      2.333333       3                  7.000000
# 19   1      5.666667       6                  7.000000
# 20   2      6.666667       6                  6.000000
# 21   3      3.000000       3                  7.000000
# 22   1      2.000000       3                  7.000000
# 23   2      6.000000       6                  6.000000
# 24   3      6.000000       7                  6.000000
# 25   1      5.333333       6                  7.000000
# 26   2      6.000000       6                  5.666667
# 27   3      2.000000       3                  7.000000
# 28   1      2.000000       3                  7.000000
# 29   2      6.000000       6                  6.666667
# 30   3      6.000000       6                  6.666667
# ⋮    ⋮      ⋮              ⋮                  ⋮
# 1291 1      2.000000       3                  7.000000
# 1292 2      7.000000       6                  5.000000
# 1293 3      6.000000       5                  6.000000
# 1294 1      5.666667       6                  6.666667
# 1295 2      6.000000       6                  4.666667
# 1296 3      2.000000       3                  7.000000
# 1297 1      2.000000       3                  7.000000
# 1298 2      6.000000       6                  5.000000
# 1299 3      7.000000       7                  5.000000
# 1300 1      6.000000       7                  6.666667
# 1301 2      2.000000       3                  7.000000
# 1302 3      6.000000       6                  7.000000
# 1303 1      2.000000       3                  7.000000
# 1304 2      6.000000       6                  6.666667
# 1305 3      7.000000       6                  5.666667
# 1306 1      4.000000       5                  7.000000
# 1307 2      3.000000       4                  7.000000
# 1308 3      6.000000       6                  6.000000
# 1309 1      2.333333       3                  7.000000
# 1310 2      7.000000       6                  4.666667
# 1311 3      5.000000       4                  7.000000
# 1312 1      2.000000       3                  7.000000
# 1313 2      6.000000       6                  6.000000
# 1314 3      5.000000       5                  6.000000
# 1315 1      6.000000       5                  6.666667
# 1316 2      6.000000       6                  5.666667
# 1317 3      3.000000       3                  6.666667
# 1318 1      7.000000       6                  6.666667
# 1319 2      3.000000       3                  7.000000
# 1320 3      6.000000       6                  6.000000
#      product_involvement perceived_information willingness_reveal
# 1    5.428571            6.2                   1.8
# 2    5.428571            5.2                   2.8
# 3    5.428571            6.2                   1.8
# 4    5.285714            5.2                   3.2
# 5    5.285714            5.8                   3.2
# 6    5.285714            5.8                   3.2
# 7    5.428571            6.2                   2.8
# 8    5.428571            5.2                   3.8
# 9    5.714286            6.2                   2.8
# 10   5.285714            6.0                   2.6
# 11   5.285714            6.8                   1.2
# 12   5.285714            6.2                   2.0
# 13   6.285714            5.6                   2.8
# 14   6.142857            5.6                   2.8
# 15   6.142857            5.6                   2.8
# 16   5.285714            5.8                   2.2
# 17   5.285714            5.8                   2.2
# 18   5.285714            5.8                   2.2
# 19   5.428571            6.0                   3.2
# 20   5.428571            5.0                   4.2
# 21   5.428571            6.0                   3.2
# 22   5.428571            5.8                   2.4
# 23   5.428571            4.8                   3.4
# 24   5.428571            5.8                   2.4
# 25   5.285714            5.2                   2.8
# 26   5.285714            3.6                   3.4
# 27   5.285714            5.6                   2.4
# 28   5.428571            5.2                   2.2
# 29   5.428571            5.2                   2.2
# 30   5.428571            5.2                   2.4
# ⋮    ⋮                   ⋮                     ⋮
# 1291 5.428571            6.0                   2.2
# 1292 5.428571            5.0                   3.2
# 1293 5.428571            6.0                   2.2
# 1294 5.285714            6.2                   2.0
# 1295 5.285714            5.2                   3.2
# 1296 5.285714            6.4                   1.8
# 1297 5.428571            5.4                   2.6
# 1298 5.428571            5.4                   2.6
# 1299 5.428571            5.4                   2.6
# 1300 5.571429            5.2                   3.2
# 1301 5.428571            5.6                   3.2
# 1302 5.428571            5.6                   3.2
# 1303 5.285714            6.2                   3.0
# 1304 5.285714            6.2                   3.8
# 1305 5.285714            5.0                   4.4
# 1306 5.285714            5.4                   2.4
# 1307 5.285714            5.4                   2.4
# 1308 5.285714            4.4                   4.0
# 1309 5.285714            6.2                   2.8
# 1310 5.285714            4.6                   4.4
# 1311 5.285714            6.2                   2.6
# 1312 5.285714            5.4                   2.8
# 1313 5.285714            5.4                   2.8
# 1314 5.285714            5.4                   3.2
# 1315 5.285714            5.4                   3.0
# 1316 5.285714            4.4                   4.0
# 1317 5.285714            5.4                   3.0
# 1318 5.571429            5.2                   3.8
# 1319 5.142857            5.4                   3.6
# 1320 5.571429            5.4                   4.2

# %%
variablen <- c("price_fairness", "purchase_intention", "future_search_intention", "product_involvement")
n <- length(variablen)

cor_matrix <- matrix("", nrow = n, ncol = n, dimnames = list(variablen, variablen))
p_values <- matrix(NA, nrow = n, ncol = n, dimnames = list(variablen, variablen))

for (i in seq_along(variablen)) {
  for (j in seq_along(variablen)) {
    if (i == j) {
      cor_matrix[i, j] <- "1.000"
    } else {
      test <- cor.test(df[[variablen[i]]], df[[variablen[j]]])
      r <- test$estimate
      p <- test$p.value
      stars <- if (p < 0.01) {
        "***"
      } else if (p < 0.05) {
        "**"
      } else if (p < 0.10) {
        "*"
      } else {
        ""
      }
      cor_matrix[i, j] <- sprintf("%.3f%s", r, stars)
      p_values[i, j] <- p
    }
  }
}

means <- round(colMeans(df[variablen], na.rm = TRUE), 2)
stds <- round(apply(df[variablen], 2, sd, na.rm = TRUE), 2)

cor_matrix <- rbind(cor_matrix, Mean = as.character(means), `Standard Deviation` = as.character(stds))
cor_matrix

write.xlsx(cor_matrix, 'Cor_Matrix_S2_Normal.xlsx')
# Out:
#                         price_fairness purchase_intention
# price_fairness          1.000          0.942***
# purchase_intention      0.942***       1.000
# future_search_intention -0.630***      -0.610***
# product_involvement     0.118***       0.133***
# Mean                    4.98           4.9
# Standard Deviation      1.96           1.48
#                         future_search_intention product_involvement
# price_fairness          -0.630***               0.118***
# purchase_intention      -0.610***               0.133***
# future_search_intention 1.000                   -0.075***
# product_involvement     -0.075***               1.000
# Mean                    6.37                    5.26
# Standard Deviation      0.75                    0.3

# %%
library(psych)

print("Cronbach's alpha")

categories <- c("01 Distributive Price Fairness Perception",
                "03 Purchase Intention",
                "04 Future Search Intention",
                "08 Product Involvement")

for (cat in categories) {
  cols <- column_group_index(cat)
  if (length(cols) == 0) next
  items <- df[, cols, drop = FALSE]
  alpha_val <- psych::alpha(items)$total$raw_alpha
  print(paste(cat, ":", alpha_val))
}
# Out:
# [1] "Cronbach's alpha"
# [1] "01 Distributive Price Fairness Perception : 0.997281050232203"
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# The Chi square is thus based upon observed correlations.
#
# In smc, smcs < 0 were set to .0
# [1] "03 Purchase Intention : 0.999884751614791"
# [1] "04 Future Search Intention : 0.955846140435938"
# [1] "08 Product Involvement : 0.839969706167646"

# %%
df$age <- as.numeric(df[["002"]])
df$gender <- df[["001"]]
df$dummy_gender <- as.integer(df$gender == "b")
df$income <- df[["005"]]
df$dummy_income <- as.integer(df$income %in% c("d", "e", "f"))
df$frequency <- df[[column_group_index("12 Frequency of Online Purchases")[1]]]
df$dummy_frequency <- as.integer(df$frequency == "f")
df$favored <- as.integer(df$Sce == "Favored Customer")
df$disadvantaged <- as.integer(df$Sce == "Disadvantaged Customer")
df$scenario <- ifelse(df$Sce == "Favored Customer", 1,
               ifelse(df$Sce == "Disadvantaged Customer", 2, 0))
df$education = df[["003"]]
df$employment = df[["004"]]
df$social_media_usage = df[[column_group_index("14 Social Media Usage")[1]]]

df$internet_usage = df[[column_group_index("11 Daily Internet Usage")[1]]]
df$money_spent = df[[column_group_index("13 Money Spent for Online Purchases")[1]]]

df$is_device_used = df[["010"]]
df$is_geographical_location = df[["011"]]
df$is_past_browsing_behavior = df[["012"]]
df$is_past_shopping_behavior = df[["013"]]
df$is_social_media_data = df[["014"]]

df$wr_device_used = df[["015"]]
df$wr_geographical_location = df[["016"]]
df$wr_past_browsing_behavior = df[["017"]]
df$wr_past_shopping_behavior = df[["018"]]
df$wr_social_media_data = df[["019"]]


df
# Out:
#      Tri Sce                    001 002 003 004 005 006 007 008 ⋯
# 1      0 Disadvantaged Customer a   42  e   g   f   c   c   g   ⋯
# 2      0 Same Price             a   42  e   g   f   c   c   g   ⋯
# 3      0 Favored Customer       a   42  e   g   f   c   c   g   ⋯
# 4      1 Same Price             b   57  e   b   c   c   c   d   ⋯
# 5      1 Disadvantaged Customer b   57  e   b   c   c   c   d   ⋯
# 6      1 Favored Customer       b   57  e   b   c   c   c   d   ⋯
# 7     10 Favored Customer       b   57  a   a   c   b   c   d   ⋯
# 8     10 Same Price             b   57  a   a   c   b   c   d   ⋯
# 9     10 Disadvantaged Customer b   57  a   a   c   b   c   d   ⋯
# 10   100 Same Price             a   57  c   a   d   c   c   e   ⋯
# 11   100 Favored Customer       a   57  c   a   d   c   c   e   ⋯
# 12   100 Disadvantaged Customer a   57  c   a   d   c   c   e   ⋯
# 13   101 Same Price             a   47  e   a   c   c   c   d   ⋯
# 14   101 Favored Customer       a   47  e   a   c   c   c   d   ⋯
# 15   101 Disadvantaged Customer a   47  e   a   c   c   c   d   ⋯
# 16   102 Disadvantaged Customer a   42  d   a   a   c   c   d   ⋯
# 17   102 Same Price             a   42  d   a   a   c   c   d   ⋯
# 18   102 Favored Customer       a   42  d   a   a   c   c   d   ⋯
# 19   103 Disadvantaged Customer b   47  b   a   e   c   c   e   ⋯
# 20   103 Same Price             b   47  b   a   e   c   c   e   ⋯
# 21   103 Favored Customer       b   47  b   a   e   c   c   e   ⋯
# 22   104 Favored Customer       a   57  e   b   e   c   c   e   ⋯
# 23   104 Same Price             a   57  e   b   e   c   c   e   ⋯
# 24   104 Disadvantaged Customer a   57  e   b   e   c   c   e   ⋯
# 25   105 Disadvantaged Customer a   47  a   a   d   c   c   e   ⋯
# 26   105 Same Price             a   47  a   a   d   c   c   e   ⋯
# 27   105 Favored Customer       a   47  a   a   d   c   c   e   ⋯
# 28   106 Favored Customer       b   47  d   a   a   c   c   d   ⋯
# 29   106 Same Price             b   47  d   a   a   c   c   d   ⋯
# 30   106 Disadvantaged Customer b   47  d   a   a   c   c   d   ⋯
# ⋮    ⋮   ⋮                      ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋱
# 1291 90  Favored Customer       b   47  e   a   d   c   c   e   ⋯
# 1292 90  Same Price             b   47  e   a   d   c   c   e   ⋯
# 1293 90  Disadvantaged Customer b   47  e   a   d   c   c   e   ⋯
# 1294 91  Disadvantaged Customer a   57  d   a   c   c   c   e   ⋯
# 1295 91  Same Price             a   57  d   a   c   c   c   e   ⋯
# 1296 91  Favored Customer       a   57  d   a   c   c   c   e   ⋯
# 1297 92  Favored Customer       b   57  e   b   e   c   c   f   ⋯
# 1298 92  Disadvantaged Customer b   57  e   b   e   c   c   f   ⋯
# 1299 92  Same Price             b   57  e   b   e   c   c   f   ⋯
# 1300 93  Same Price             a   57  c   b   d   c   c   d   ⋯
# 1301 93  Favored Customer       a   57  c   b   d   c   c   d   ⋯
# 1302 93  Disadvantaged Customer a   57  c   b   d   c   c   d   ⋯
# 1303 94  Favored Customer       a   47  d   a   c   c   c   d   ⋯
# 1304 94  Disadvantaged Customer a   47  d   a   c   c   c   d   ⋯
# 1305 94  Same Price             a   47  d   a   c   c   c   d   ⋯
# 1306 95  Disadvantaged Customer b   57  e   g   c   c   c   d   ⋯
# 1307 95  Favored Customer       b   57  e   g   c   c   c   d   ⋯
# 1308 95  Same Price             b   57  e   g   c   c   c   d   ⋯
# 1309 96  Favored Customer       b   47  a   a   d   c   c   e   ⋯
# 1310 96  Same Price             b   47  a   a   d   c   c   e   ⋯
# 1311 96  Disadvantaged Customer b   47  a   a   d   c   c   e   ⋯
# 1312 97  Favored Customer       b   47  b   a   d   c   c   d   ⋯
# 1313 97  Same Price             b   47  b   a   d   c   c   d   ⋯
# 1314 97  Disadvantaged Customer b   47  b   a   d   c   c   d   ⋯
# 1315 98  Disadvantaged Customer b   57  b   b   c   c   c   d   ⋯
# 1316 98  Same Price             b   57  b   b   c   c   c   d   ⋯
# 1317 98  Favored Customer       b   57  b   b   c   c   c   d   ⋯
# 1318 99  Same Price             a   57  e   f   e   c   c   e   ⋯
# 1319 99  Favored Customer       a   57  e   f   e   c   c   e   ⋯
# 1320 99  Disadvantaged Customer a   57  e   f   e   c   c   e   ⋯
#      is_device_used is_geographical_location is_past_browsing_behavior
# 1    5              6                        7
# 2    4              5                        6
# 3    5              6                        7
# 4    5              6                        5
# 5    5              6                        6
# 6    5              6                        6
# 7    5              6                        7
# 8    4              5                        6
# 9    5              6                        7
# 10   5              6                        6
# 11   6              7                        7
# 12   6              6                        6
# 13   5              6                        6
# 14   5              6                        6
# 15   5              6                        6
# 16   5              6                        6
# 17   5              6                        6
# 18   5              6                        6
# 19   5              6                        6
# 20   4              5                        5
# 21   5              6                        6
# 22   5              6                        6
# 23   4              5                        5
# 24   5              6                        6
# 25   4              5                        6
# 26   3              3                        4
# 27   5              6                        6
# 28   4              5                        6
# 29   4              5                        6
# 30   4              5                        6
# ⋮    ⋮              ⋮                        ⋮
# 1291 5              6                        6
# 1292 4              5                        5
# 1293 5              6                        6
# 1294 5              6                        7
# 1295 4              5                        6
# 1296 6              6                        7
# 1297 5              6                        5
# 1298 5              6                        5
# 1299 5              6                        5
# 1300 5              6                        5
# 1301 5              6                        6
# 1302 5              6                        6
# 1303 5              6                        7
# 1304 5              6                        7
# 1305 4              5                        5
# 1306 4              5                        6
# 1307 4              5                        6
# 1308 3              4                        5
# 1309 5              6                        7
# 1310 4              5                        5
# 1311 5              6                        7
# 1312 5              4                        6
# 1313 5              4                        6
# 1314 5              4                        6
# 1315 5              6                        5
# 1316 4              5                        4
# 1317 5              6                        5
# 1318 5              6                        5
# 1319 5              6                        5
# 1320 5              6                        5
#      is_past_shopping_behavior is_social_media_data wr_device_used
# 1    6                         7                    3
# 2    5                         6                    4
# 3    6                         7                    3
# 4    4                         6                    4
# 5    5                         7                    4
# 6    5                         7                    4
# 7    7                         6                    3
# 8    6                         5                    4
# 9    7                         6                    3
# 10   6                         7                    4
# 11   7                         7                    2
# 12   6                         7                    3
# 13   5                         6                    4
# 14   5                         6                    4
# 15   5                         6                    4
# 16   5                         7                    3
# 17   5                         7                    3
# 18   5                         7                    3
# 19   6                         7                    4
# 20   5                         6                    5
# 21   6                         7                    4
# 22   5                         7                    3
# 23   4                         6                    4
# 24   5                         7                    3
# 25   5                         6                    4
# 26   4                         4                    5
# 27   5                         6                    3
# 28   5                         6                    3
# 29   5                         6                    3
# 30   5                         6                    4
# ⋮    ⋮                         ⋮                    ⋮
# 1291 6                         7                    3
# 1292 5                         6                    4
# 1293 6                         7                    3
# 1294 7                         6                    3
# 1295 6                         5                    4
# 1296 7                         6                    2
# 1297 4                         7                    3
# 1298 4                         7                    3
# 1299 4                         7                    3
# 1300 4                         6                    4
# 1301 5                         6                    4
# 1302 5                         6                    4
# 1303 6                         7                    3
# 1304 6                         7                    4
# 1305 5                         6                    5
# 1306 6                         6                    3
# 1307 6                         6                    3
# 1308 5                         5                    5
# 1309 7                         6                    3
# 1310 5                         4                    5
# 1311 7                         6                    3
# 1312 6                         6                    3
# 1313 6                         6                    3
# 1314 6                         6                    4
# 1315 5                         6                    4
# 1316 4                         5                    5
# 1317 5                         6                    4
# 1318 4                         6                    4
# 1319 5                         6                    4
# 1320 5                         6                    5
#      wr_geographical_location wr_past_browsing_behavior
# 1    2                        1
# 2    3                        2
# 3    2                        1
# 4    3                        3
# 5    3                        3
# 6    3                        3
# 7    3                        2
# 8    4                        3
# 9    3                        2
# 10   3                        2
# 11   1                        1
# 12   2                        2
# 13   3                        2
# 14   3                        2
# 15   3                        2
# 16   2                        2
# 17   2                        2
# 18   2                        2
# 19   3                        3
# 20   4                        4
# 21   3                        3
# 22   2                        2
# 23   3                        3
# 24   2                        2
# 25   3                        2
# 26   4                        3
# 27   2                        2
# 28   2                        2
# 29   2                        2
# 30   2                        2
# ⋮    ⋮                        ⋮
# 1291 2                        2
# 1292 3                        3
# 1293 2                        2
# 1294 2                        1
# 1295 3                        3
# 1296 2                        1
# 1297 2                        3
# 1298 2                        3
# 1299 2                        3
# 1300 3                        3
# 1301 3                        3
# 1302 3                        3
# 1303 4                        2
# 1304 4                        3
# 1305 5                        4
# 1306 2                        2
# 1307 2                        2
# 1308 4                        4
# 1309 4                        2
# 1310 5                        4
# 1311 3                        2
# 1312 4                        2
# 1313 4                        2
# 1314 4                        3
# 1315 3                        3
# 1316 4                        4
# 1317 3                        3
# 1318 3                        4
# 1319 3                        4
# 1320 4                        4
#      wr_past_shopping_behavior wr_social_media_data
# 1    2                         1
# 2    3                         2
# 3    2                         1
# 4    4                         2
# 5    4                         2
# 6    4                         2
# 7    4                         2
# 8    5                         3
# 9    4                         2
# 10   3                         1
# 11   1                         1
# 12   2                         1
# 13   3                         2
# 14   3                         2
# 15   3                         2
# 16   3                         1
# 17   3                         1
# 18   3                         1
# 19   4                         2
# 20   5                         3
# 21   4                         2
# 22   3                         2
# 23   4                         3
# 24   3                         2
# 25   3                         2
# 26   3                         2
# 27   3                         2
# 28   3                         1
# 29   3                         1
# 30   3                         1
# ⋮    ⋮                         ⋮
# 1291 3                         1
# 1292 4                         2
# 1293 3                         1
# 1294 2                         2
# 1295 3                         3
# 1296 2                         2
# 1297 4                         1
# 1298 4                         1
# 1299 4                         1
# 1300 4                         2
# 1301 4                         2
# 1302 4                         2
# 1303 4                         2
# 1304 5                         3
# 1305 5                         3
# 1306 3                         2
# 1307 3                         2
# 1308 4                         3
# 1309 2                         3
# 1310 4                         4
# 1311 2                         3
# 1312 3                         2
# 1313 3                         2
# 1314 3                         2
# 1315 3                         2
# 1316 4                         3
# 1317 3                         2
# 1318 5                         3
# 1319 4                         3
# 1320 5                         3

# %%
process(data = df,
        model = 4,
        y = "purchase_intention", 
        x = "scenario",
        mcx = 1,
        m = "price_fairness",
        cov = c("age", "dummy_gender", "dummy_income"),
        boot = 10000,
        seed = 654321)
# Out:
# ********************* PROCESS for R Version 4.3.1 *********************
#
#            Written by Andrew F. Hayes, Ph.D.  www.afhayes.com
#    Documentation available in Hayes (2022). www.guilford.com/p/hayes3
#
# ***********************************************************************
#
# Model : 4
#     Y : purchase_intention
#     X : scenario
#     M : price_fairness
#
# Covariates:
#        age dummy_gender dummy_income
#
# Sample size: 1320
#
# Custom seed: 654321
#
# Coding of categorical X variable for analysis:
#    scenario        X1        X2
#      0.0000    0.0000    0.0000
#      1.0000    1.0000    0.0000
#      2.0000    0.0000    1.0000
#
# ***********************************************************************
# Outcome Variable: price_fairness
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.9579    0.9175    0.3175 2922.4058    5.0000 1314.0000    0.0000
#
# Model:
#                  coeff        se         t         p      LLCI      ULCI
# constant        6.8786    0.1035   66.4395    0.0000    6.6755    7.0818
# X1             -4.4061    0.0380 -115.9882    0.0000   -4.4806   -4.3315
# X2             -1.0841    0.0380  -28.5384    0.0000   -1.1586   -1.0096
# age            -0.0016    0.0018   -0.8894    0.3739   -0.0051    0.0019
# dummy_gender   -0.0105    0.0316   -0.3315    0.7403   -0.0725    0.0516
# dummy_income    0.0237    0.0331    0.7163    0.4739   -0.0412    0.0885
#
# ***********************************************************************
# Outcome Variable: purchase_intention
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.9465    0.8958    0.2291 1880.8059    6.0000 1313.0000    0.0000
#
# Model:
#                    coeff        se         t         p      LLCI      ULCI
# constant          2.6596    0.1836   14.4843    0.0000    2.2994    3.0198
# X1               -0.8638    0.1082   -7.9857    0.0000   -1.0761   -0.6516
# X2               -0.0561    0.0411   -1.3661    0.1721   -0.1367    0.0245
# price_fairness    0.5213    0.0234   22.2450    0.0000    0.4753    0.5672
# age              -0.0020    0.0015   -1.3383    0.1810   -0.0050    0.0009
# dummy_gender      0.0202    0.0269    0.7499    0.4535   -0.0326    0.0729
# dummy_income      0.0775    0.0281    2.7607    0.0058    0.0224    0.1326
#
# ***********************************************************************
# Bootstrapping progress:
#   |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>| 100%
#
# **************** DIRECT AND INDIRECT EFFECTS OF X ON Y ****************
#
# Relative direct effects of X on Y:
#       effect        se         t         p      LLCI      ULCI
# X1   -0.8638    0.1082   -7.9857    0.0000   -1.0761   -0.6516
# X2   -0.0561    0.0411   -1.3661    0.1721   -0.1367    0.0245
#
# Omnibus test of direct effect of X on Y:
#     R2-chng         F       df1       df2         p
#      0.0080   50.2698    2.0000 1313.0000    0.0000
#
# ----------
#
# Relative indirect effects of X on Y:
#
# scenario    ->    price_fairness    ->    purchase_intention
#
#       Effect    BootSE  BootLLCI  BootULCI
# X1   -2.2968    0.1289   -2.5490   -2.0393
# X2   -0.5651    0.0424   -0.6502   -0.4814
#
# ******************** ANALYSIS NOTES AND ERRORS ************************
#
# Level of confidence for all confidence intervals in output: 95
#
# Number of bootstraps for percentile bootstrap confidence intervals: 5000

# %%
process(data = df,
        model = 4,
        y = "future_search_intention", 
        x = "scenario",
        mcx = 1,
        m = "price_fairness",
        cov = c("age", "dummy_gender", "dummy_income"),
        boot = 10000,
        seed = 654321)
# Out:
# ********************* PROCESS for R Version 4.3.1 *********************
#
#            Written by Andrew F. Hayes, Ph.D.  www.afhayes.com
#    Documentation available in Hayes (2022). www.guilford.com/p/hayes3
#
# ***********************************************************************
#
# Model : 4
#     Y : future_search_intention
#     X : scenario
#     M : price_fairness
#
# Covariates:
#        age dummy_gender dummy_income
#
# Sample size: 1320
#
# Custom seed: 654321
#
# Coding of categorical X variable for analysis:
#    scenario        X1        X2
#      0.0000    0.0000    0.0000
#      1.0000    1.0000    0.0000
#      2.0000    0.0000    1.0000
#
# ***********************************************************************
# Outcome Variable: price_fairness
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.9579    0.9175    0.3175 2922.4058    5.0000 1314.0000    0.0000
#
# Model:
#                  coeff        se         t         p      LLCI      ULCI
# constant        6.8786    0.1035   66.4395    0.0000    6.6755    7.0818
# X1             -4.4061    0.0380 -115.9882    0.0000   -4.4806   -4.3315
# X2             -1.0841    0.0380  -28.5384    0.0000   -1.1586   -1.0096
# age            -0.0016    0.0018   -0.8894    0.3739   -0.0051    0.0019
# dummy_gender   -0.0105    0.0316   -0.3315    0.7403   -0.0725    0.0516
# dummy_income    0.0237    0.0331    0.7163    0.4739   -0.0412    0.0885
#
# ***********************************************************************
# Outcome Variable: future_search_intention
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.6493    0.4216    0.3267  159.4923    6.0000 1313.0000    0.0000
#
# Model:
#                    coeff        se         t         p      LLCI      ULCI
# constant          7.4548    0.2193   33.9942    0.0000    7.0246    7.8850
# X1                0.1257    0.1292    0.9729    0.3308   -0.1278    0.3791
# X2                0.2760    0.0490    5.6269    0.0000    0.1798    0.3722
# price_fairness   -0.2311    0.0280   -8.2577    0.0000   -0.2860   -0.1762
# age              -0.0022    0.0018   -1.2071    0.2276   -0.0057    0.0014
# dummy_gender     -0.0018    0.0321   -0.0547    0.9564   -0.0647    0.0612
# dummy_income      0.0678    0.0335    2.0214    0.0434    0.0020    0.1336
#
# ***********************************************************************
# Bootstrapping progress:
#   |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>| 100%
#
# **************** DIRECT AND INDIRECT EFFECTS OF X ON Y ****************
#
# Relative direct effects of X on Y:
#       effect        se         t         p      LLCI      ULCI
# X1    0.1257    0.1292    0.9729    0.3308   -0.1278    0.3791
# X2    0.2760    0.0490    5.6269    0.0000    0.1798    0.3722
#
# Omnibus test of direct effect of X on Y:
#     R2-chng         F       df1       df2         p
#      0.0219   24.8961    2.0000 1313.0000    0.0000
#
# ----------
#
# Relative indirect effects of X on Y:
#
# scenario    ->    price_fairness    ->    future_search_intention
#
#       Effect    BootSE  BootLLCI  BootULCI
# X1    1.0183    0.0961    0.8318    1.2013
# X2    0.2505    0.0259    0.2009    0.2999
#
# ******************** ANALYSIS NOTES AND ERRORS ************************
#
# Level of confidence for all confidence intervals in output: 95
#
# Number of bootstraps for percentile bootstrap confidence intervals: 5000

# %%
cat_list <- c("00 Demographics", 
              "11 Daily Internet Usage", 
              "12 Frequency of Online Purchases", 
              "13 Money Spent for Online Purchases", 
              "14 Social Media Usage")

freq_table <- data.frame()

for (cat in cat_list) {
  cols <- column_group_index(cat)
  valid_cols <- intersect(cols, names(df))
  if (length(valid_cols) == 0) next
  for (col in valid_cols) {
    if(!(col %in% c("002"))) {
        tbl <- table(df[[col]], useNA = "ifany")
        total <- sum(tbl)
        tmp <- data.frame(
          "Question" = cat,
          "Column"   = col,
          "Response" = names(tbl),
          "Absolute frequency" = as.numeric(tbl),
          "Relative frequency (in %)" = round(100 * as.numeric(tbl) / total, 2),
          check.names = FALSE,
          stringsAsFactors = FALSE
        )
        freq_table <- rbind(freq_table, tmp)
    }
  }
}

freq_table
write.xlsx(freq_table, 'Descriptives_S2_Normal.xlsx')
# Out:
#    Question                            Column Response Absolute frequency
# 1  00 Demographics                     001    a         783
# 2  00 Demographics                     001    b         537
# 3  00 Demographics                     003    a         231
# 4  00 Demographics                     003    b         135
# 5  00 Demographics                     003    c          72
# 6  00 Demographics                     003    d         372
# 7  00 Demographics                     003    e         501
# 8  00 Demographics                     003    g           9
# 9  00 Demographics                     004    a         609
# 10 00 Demographics                     004    b         276
# 11 00 Demographics                     004    c          72
# 12 00 Demographics                     004    d           6
# 13 00 Demographics                     004    e           3
# 14 00 Demographics                     004    f         180
# 15 00 Demographics                     004    g         174
# 16 00 Demographics                     005    a          69
# 17 00 Demographics                     005    b          84
# 18 00 Demographics                     005    c         345
# 19 00 Demographics                     005    d         270
# 20 00 Demographics                     005    e         357
# 21 00 Demographics                     005    f         195
# 22 11 Daily Internet Usage             006    a           6
# 23 11 Daily Internet Usage             006    b         114
# 24 11 Daily Internet Usage             006    c        1191
# 25 11 Daily Internet Usage             006    d           9
# 26 12 Frequency of Online Purchases    007    b           6
# 27 12 Frequency of Online Purchases    007    c        1290
# 28 12 Frequency of Online Purchases    007    d          24
# 29 13 Money Spent for Online Purchases 008    c           9
# 30 13 Money Spent for Online Purchases 008    d         426
# 31 13 Money Spent for Online Purchases 008    e         594
# 32 13 Money Spent for Online Purchases 008    f         225
# 33 13 Money Spent for Online Purchases 008    g          66
# 34 14 Social Media Usage               009    a        1320
#    Relative frequency (in %)
# 1   59.32
# 2   40.68
# 3   17.50
# 4   10.23
# 5    5.45
# 6   28.18
# 7   37.95
# 8    0.68
# 9   46.14
# 10  20.91
# 11   5.45
# 12   0.45
# 13   0.23
# 14  13.64
# 15  13.18
# 16   5.23
# 17   6.36
# 18  26.14
# 19  20.45
# 20  27.05
# 21  14.77
# 22   0.45
# 23   8.64
# 24  90.23
# 25   0.68
# 26   0.45
# 27  97.73
# 28   1.82
# 29   0.68
# 30  32.27
# 31  45.00
# 32  17.05
# 33   5.00
# 34 100.00

# %%
library(dplyr)

cat <- "17 Realism Check"
cols <- column_group_index(cat)

for (col in cols) {
  cat("ANOVA for:", col, "\n\n")
  
  # Descriptive statistics
  summary_df <- df %>%
    group_by(Sce) %>%
    summarize(
      M  = round(mean(.data[[col]], na.rm = TRUE), 2),
      SD = round(sd(.data[[col]], na.rm = TRUE), 2),
      n  = n()
    )
  print(summary_df)
  
  # One-way ANOVA
  fit <- aov(df[[col]] ~ Sce, data = df)
  print(summary(fit))
  
  cat("\n----------------------------------------\n\n")
}
# Out:
# ANOVA for: 037
#
# # A tibble: 3 × 4
#   Sce                        M    SD     n
#   <chr>                  <dbl> <dbl> <int>
# 1 Disadvantaged Customer  6.98  0.13   440
# 2 Favored Customer        6.98  0.14   440
# 3 Same Price              7     0.07   440
#               Df Sum Sq Mean Sq F value Pr(>F)
# Sce            2  0.065 0.03258   2.299  0.101
# Residuals   1317 18.661 0.01417
#
# ----------------------------------------
#
# ANOVA for: 038
#
# # A tibble: 3 × 4
#   Sce                        M    SD     n
#   <chr>                  <dbl> <dbl> <int>
# 1 Disadvantaged Customer  6.01  0.21   440
# 2 Favored Customer        6     0.22   440
# 3 Same Price              6.16  0.36   440
#               Df Sum Sq Mean Sq F value Pr(>F)
# Sce            2   6.91   3.457   45.91 <2e-16 ***
# Residuals   1317  99.16   0.075
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ----------------------------------------

# %%
vars <- c("gender", "education", "employment", "social_media_usage")

for (i in 1:length(vars)) { 
    for (j in 1:i) {
        if (i != j){
            cat("Chi-squared test for", vars[i], "vs", vars[j])
            tab <- table(df[[vars[i]]], df[[vars[j]]])
            print(tab)
            test <- chisq.test(tab)
            print(test)
        }
    }
}
# Out:
# Chi-squared test for education vs gender
#       a   b
#   a 141  90
#   b  78  57
#   c  45  27
#   d 255 117
#   e 255 246
#   g   9   0
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 34.743, df = 5, p-value = 1.693e-06
#
# Chi-squared test for employment vs gender
#       a   b
#   a 402 207
#   b 135 141
#   c  51  21
#   d   0   6
#   e   3   0
#   f  84  96
#   g 108  66
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 50.93, df = 6, p-value = 3.059e-09
#
# Chi-squared test for employment vs education
#       a   b   c   d   e   g
#   a 201 108  24 222  54   0
#   b  12  15  36  75 132   6
#   c   6   6   3  24  30   3
#   d   0   0   0   0   6   0
#   e   0   0   0   0   3   0
#   f   6   6   9   3 156   0
#   g   6   0   0  48 120   0
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 665.65, df = 30, p-value < 2.2e-16
#
# Chi-squared test for social_media_usage vs gender
#       a   b
#   a 783 537
#
# 	Chi-squared test for given probabilities
#
# data:  tab
# X-squared = 45.845, df = 1, p-value = 1.28e-11
#
# Chi-squared test for social_media_usage vs education
#       a   b   c   d   e   g
#   a 231 135  72 372 501   9
#
# 	Chi-squared test for given probabilities
#
# data:  tab
# X-squared = 799.25, df = 5, p-value < 2.2e-16
#
# Chi-squared test for social_media_usage vs employment
#       a   b   c   d   e   f   g
#   a 609 276  72   6   3 180 174
#
# 	Chi-squared test for given probabilities
#
# data:  tab
# X-squared = 1410.9, df = 6, p-value < 2.2e-16

# %%
vars <- c("product_involvement", "age", "income", "internet_usage", "frequency", "money_spent")

for (var in vars) {
  cat("Kruskal-Wallis test for", var, "vs Sce\n")
  result <- kruskal.test(df[[var]] ~ df$Sce)
  print(result)
  cat("\n--------------------------------\n\n")
}
# Out:
# Kruskal-Wallis test for product_involvement vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 12.847, df = 2, p-value = 0.001623
#
#
# --------------------------------
#
# Kruskal-Wallis test for age vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------
#
# Kruskal-Wallis test for income vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------
#
# Kruskal-Wallis test for internet_usage vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------
#
# Kruskal-Wallis test for frequency vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------
#
# Kruskal-Wallis test for money_spent vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------

# %%
library(ez)
library(reshape2)
library(rstatix)

print("ANOVA: Price Fairness Perception")

df <- df %>%
  mutate(
    Tri = factor(Tri),
    Sce = factor(Sce)
  )

anova_results <- ezANOVA(
  data      = df,
  dv        = price_fairness,
  wid       = Tri,
  within    = Sce,
  detailed  = TRUE,
  type      = 3
)

print(anova_results$ANOVA)
print(anova_results$Mauchly)
print(anova_results$`Sphericity Corrections`)
# Out:
# Attaching package: ‘rstatix’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
# [1] "ANOVA: Price Fairness Perception"
#        Effect DFn DFd       SSn      SSd          F p p<.05       ges
# 1 (Intercept)   1 439 32694.046 110.3987 130007.801 0     * 0.9873836
# 2         Sce   2 878  4638.202 307.3534   6624.853 0     * 0.9173742
#   Effect         W            p p<.05
# 2    Sce 0.7693028 1.135819e-25     *
#   Effect       GGe p[GG] p[GG]<.05      HFe p[HF] p[HF]<.05
# 2    Sce 0.8125475     0         * 0.815138     0         *

# %%
print("ANOVA: Purchase intention")

df <- df %>%
  mutate(
    Tri = factor(Tri),
    Sce = factor(Sce)
  )

anova_results <- ezANOVA(
  data      = df,
  dv        = purchase_intention,
  wid       = Tri,
  within    = Sce,
  detailed  = TRUE,
  type      = 3
)

print(anova_results$ANOVA)
print(anova_results$Mauchly)
print(anova_results$`Sphericity Corrections`)
# Out:
# [1] "ANOVA: Purchase intention"
#        Effect DFn DFd       SSn      SSd         F p p<.05       ges
# 1 (Intercept)   1 439 31673.603 166.0266 83749.904 0     * 0.9869677
# 2         Sce   2 878  2467.499 252.2047  4295.051 0     * 0.8550692
#   Effect         W            p p<.05
# 2    Sce 0.8439915 7.379782e-17     *
#   Effect       GGe p[GG] p[GG]<.05       HFe p[HF] p[HF]<.05
# 2    Sce 0.8650456     0         * 0.8681596     0         *

# %%
print("ANOVA: Future search intention")

df <- df %>%
  mutate(
    Tri = factor(Tri),
    Sce = factor(Sce)
  )

anova_results <- ezANOVA(
  data      = df,
  dv        = future_search_intention,
  wid       = Tri,
  within    = Sce,
  detailed  = TRUE,
  type      = 3
)

print(anova_results$ANOVA)
print(anova_results$Mauchly)
print(anova_results$`Sphericity Corrections`)
# Out:
# [1] "ANOVA: Future search intention"
#        Effect DFn DFd        SSn      SSd           F             p p<.05
# 1 (Intercept)   1 439 53505.4667 227.2741 103350.5470  0.000000e+00     *
# 2         Sce   2 878   288.4975 225.8729    560.7153 1.247984e-157     *
#        ges
# 1 0.991602
# 2 0.388997
#   Effect         W         p p<.05
# 2    Sce 0.9948818 0.3250535
#   Effect       GGe         p[GG] p[GG]<.05       HFe         p[HF] p[HF]<.05
# 2    Sce 0.9949079 7.616015e-157         * 0.9994263 1.530078e-157         *

# %%
column_pairs <- list(
  c("Same Price", "Disadvantaged Customer"),
  c("Same Price", "Favored Customer"),
  c("Disadvantaged Customer", "Favored Customer")
)

df_by_sce <- split(df, df$Sce)

for (metric in c("price_fairness", "purchase_intention", "future_search_intention")) {
    cat("Metric:", metric, "\n")
    
    for (pair in column_pairs) {
        # Assign column names for clarity
        col1 <- pair[1]
        col2 <- pair[2]

        v1 <- df_by_sce[[col1]][[metric]]
        v2 <- df_by_sce[[col2]][[metric]]
        
        # Compute the element-wise difference and then the mean difference
        diff <- v1 - v2
        mean_diff <- mean(diff)
        
        # Perform a paired t-test to assess the significance of the mean difference
        test_result <- t.test(v1, v2, paired = TRUE)
        
        # Print the results
        cat("Comparison: ", col1, "vs", col2, "\n")
        cat("Mean Difference (", col1, " - ", col2, "): ", mean_diff, "\n", sep = "")
        print(test_result)
    }
    cat("\n----------------------------\n")
}
# Out:
# Metric: price_fairness
# Comparison:  Same Price vs Disadvantaged Customer
# Mean Difference (Same Price - Disadvantaged Customer): 1.084091
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 31.364, df = 439, p-value < 2.2e-16
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  1.016157 1.152025
# sample estimates:
# mean difference
#        1.084091
#
# Comparison:  Same Price vs Favored Customer
# Mean Difference (Same Price - Favored Customer): 4.406061
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 125.96, df = 439, p-value < 2.2e-16
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  4.337313 4.474808
# sample estimates:
# mean difference
#        4.406061
#
# Comparison:  Disadvantaged Customer vs Favored Customer
# Mean Difference (Disadvantaged Customer - Favored Customer): 3.32197
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 68.45, df = 439, p-value < 2.2e-16
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  3.226588 3.417352
# sample estimates:
# mean difference
#         3.32197
#
#
# ----------------------------
# Metric: purchase_intention
# Comparison:  Same Price vs Disadvantaged Customer
# Mean Difference (Same Price - Disadvantaged Customer): 0.6212121
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 17.883, df = 439, p-value < 2.2e-16
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  0.5529388 0.6894855
# sample estimates:
# mean difference
#       0.6212121
#
# Comparison:  Same Price vs Favored Customer
# Mean Difference (Same Price - Favored Customer): 3.160606
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 104.38, df = 439, p-value < 2.2e-16
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  3.101096 3.220116
# sample estimates:
# mean difference
#        3.160606
#
# Comparison:  Disadvantaged Customer vs Favored Customer
# Mean Difference (Disadvantaged Customer - Favored Customer): 2.539394
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 59.963, df = 439, p-value < 2.2e-16
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  2.456161 2.622627
# sample estimates:
# mean difference
#        2.539394
#
#
# ----------------------------
# Metric: future_search_intention
# Comparison:  Same Price vs Disadvantaged Customer
# Mean Difference (Same Price - Disadvantaged Customer): -0.5265152
#
# 	Paired t-test
#
# data:  v1 and v2
# t = -14.878, df = 439, p-value < 2.2e-16
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -0.5960685 -0.4569618
# sample estimates:
# mean difference
#      -0.5265152
#
# Comparison:  Same Price vs Favored Customer
# Mean Difference (Same Price - Favored Customer): -1.143939
#
# 	Paired t-test
#
# data:  v1 and v2
# t = -33.931, df = 439, p-value < 2.2e-16
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -1.210200 -1.077679
# sample estimates:
# mean difference
#       -1.143939
#
# Comparison:  Disadvantaged Customer vs Favored Customer
# Mean Difference (Disadvantaged Customer - Favored Customer): -0.6174242
#
# 	Paired t-test
#
# data:  v1 and v2
# t = -18.457, df = 439, p-value < 2.2e-16
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -0.6831706 -0.5516779
# sample estimates:
# mean difference
#      -0.6174242
#
#
# ----------------------------
