# %%
source("process/process.R")
# Out:
# ********************* PROCESS for R Version 4.3.1 *********************
#
#            Written by Andrew F. Hayes, Ph.D.  www.afhayes.com
#    Documentation available in Hayes (2022). www.guilford.com/p/hayes3
#
# ***********************************************************************
#
# PROCESS is now ready for use.
# Copyright 2020-2023 by Andrew F. Hayes ALL RIGHTS RESERVED
# Workshop schedule at http://haskayne.ucalgary.ca/CCRAM

# %%
raw_df <- read.csv("../results/pilot_final4_survey2_normal.csv", check.names = FALSE)

# %%
short_col_df <- raw_df
names(short_col_df) <- substr(names(raw_df), 1, 3)

# %%
df <- short_col_df[-1, ]

to_number_if_number <- function(s) {
  if (grepl("^[0-9]+$", s)) {
    as.integer(s)
  } else {
    s
  }
}

for (i in 1:38) {
  col_name <- sprintf("%03d", i)
  df[[col_name]] <- sapply(df[[col_name]], function(x) {
    val <- sub("^([a-zA-Z0-9]+).*", "\\1", x)
    to_number_if_number(val)
  })
}

df
# Out:
#    Tri   Sce                    001 002 003 004 005 006 007 008 ⋯ 029 030 031
# 2  0-01  Disadvantaged Customer b   55  a   c   d   c   c   g   ⋯ 7   6   4
# 3  0-02  Same Price                                             ⋯ 6   5   4
# 4  0-03  Favored Customer                                       ⋯ 5   4   5
# 5  1-01  Disadvantaged Customer b   63  e   a   f   e   d   g   ⋯ 5   6   7
# 6  1-02  Favored Customer                                       ⋯ 6   6   7
# 7  1-03  Same Price                                             ⋯ 6   4   6
# 8  10-01 Same Price             b   62  d   a   d   c   f   g   ⋯ 4   3   6
# 9  10-02 Favored Customer                                       ⋯ 5   5   6
# 10 10-03 Disadvantaged Customer                                 ⋯ 5   5   6
# 11 11-01 Same Price             b   58  a   c   e   c   f   g   ⋯ 6   4   6
# 12 11-02 Favored Customer                                       ⋯ 6   4   6
# 13 11-03 Disadvantaged Customer                                 ⋯ 6   3   6
# 14 12-01 Favored Customer       b   52  a   a   d   e   f   g   ⋯ 6   3   6
# 15 12-02 Disadvantaged Customer                                 ⋯ 6   4   6
# 16 12-03 Same Price                                             ⋯ 6   4   6
# 17 13-01 Same Price             a   53  d   a   d   c   b   d   ⋯ 6   5   6
# 18 13-02 Favored Customer                                       ⋯ 6   5   6
# 19 13-03 Disadvantaged Customer                                 ⋯ 6   5   6
# 20 14-01 Favored Customer       b   53  d   a   e   c   f   g   ⋯ 7   3   2
# 21 14-02 Same Price                                             ⋯ 6   5   6
# 22 14-03 Disadvantaged Customer                                 ⋯ 6   5   6
# 23 2-01  Same Price             b   62  d   a   e   c   f   g   ⋯ 4   5   6
# 24 2-02  Disadvantaged Customer                                 ⋯ 6   5   4
# 25 2-03  Favored Customer                                       ⋯ 6   5   6
# 26 3-01  Disadvantaged Customer b   42  e   a   c   c   e   g   ⋯ 5   3   4
# 27 3-02  Same Price                                             ⋯ 5   3   4
# 28 3-03  Favored Customer                                       ⋯ 6   5   6
# 29 4-01  Same Price             a   62  a   a   d   d   f   e   ⋯ 6   3   6
# 30 4-02  Disadvantaged Customer                                 ⋯ 6   4   6
# 31 4-03  Favored Customer                                       ⋯ 4   5   6
# 32 5-01  Same Price             b   62  d   c   d   d   f   g   ⋯ 6   5   7
# 33 5-02  Disadvantaged Customer                                 ⋯ 6   5   6
# 34 5-03  Favored Customer                                       ⋯ 6   4   6
# 35 6-01  Disadvantaged Customer b   42  b   e   c   c   f   c   ⋯ 6   4   6
# 36 6-02  Same Price                                             ⋯ 6   5   6
# 37 6-03  Favored Customer                                       ⋯ 6   4   5
# 38 7-01  Same Price             b   42  e   a   f   c   f   g   ⋯ 6   2   4
# 39 7-02  Favored Customer                                       ⋯ 6   3   4
# 40 7-03  Disadvantaged Customer                                 ⋯ 6   3   5
# 41 8-01  Same Price             b   65  d   a   d   c   e   g   ⋯ 5   6   3
# 42 8-02  Disadvantaged Customer                                 ⋯ 6   5   6
# 43 8-03  Favored Customer                                       ⋯ 6   5   6
# 44 9-01  Favored Customer       b   62  e   a   d   c   f   g   ⋯ 6   4   6
# 45 9-02  Disadvantaged Customer                                 ⋯ 6   4   6
# 46 9-03  Same Price                                             ⋯ 6   4   6
#    032 033 034 035 036 037 038
# 2  5   6   6   7   a   6   6
# 3  5   6   6   5   a   4   6
# 4  4   4   4   5   b   6   6
# 5  4   5   6   6   a   6   4
# 6  5   6   6   5   a   6   6
# 7  3   2   5   5   b   6   6
# 8  2   4   5   6   b   6   4
# 9  4   4   5   6   b   4   4
# 10 4   4   5   5   b   3   5
# 11 5   4   3   6   b   6   6
# 12 3   4   3   6   b   6   6
# 13 3   4   4   6   a   6   5
# 14 5   2   4   6   c   6   6
# 15 4   5   3   6   a   6   6
# 16 3   4   2   6   b   6   6
# 17 4   6   5   4   b   6   6
# 18 4   5   6   5   b   6   6
# 19 2   3   4   6   b   6   6
# 20 4   6   4   6   c   6   6
# 21 4   5   4   6   b   6   6
# 22 4   5   4   6   a   6   6
# 23 2   3   4   5   b   6   6
# 24 4   3   2   5   b   6   6
# 25 3   4   5   6   b   6   5
# 26 3   4   2   6   a   6   6
# 27 3   4   2   5   b   6   6
# 28 4   5   4   6   b   6   6
# 29 4   5   3   6   b   6   5
# 30 4   5   4   6   b   6   4
# 31 3   4   2   6   b   6   6
# 32 4   6   5   6   b   6   7
# 33 4   6   5   6   b   6   7
# 34 3   4   3   6   b   6   5
# 35 4   5   5   5   a   6   5
# 36 4   5   6   5   a   6   5
# 37 3   5   5   6   b   6   5
# 38 2   2   3   5   b   6   5
# 39 3   2   4   6   b   6   5
# 40 4   3   4   6   a   4   6
# 41 4   6   5   6   b   6   6
# 42 3   3   5   6   b   6   4
# 43 3   6   3   6   b   3   6
# 44 5   6   5   6   c   6   6
# 45 5   6   5   6   a   6   6
# 46 5   6   5   6   b   6   6

# %%
first_row <- as.data.frame(t(short_col_df[1, , drop = FALSE]), stringsAsFactors = FALSE)
colnames(first_row) <- "groups"

column_group_index <- function(group_name) {
  matching <- first_row$groups == group_name
  cols = rownames(first_row)[matching]
  valid_cols <- intersect(cols, names(df))
  return(valid_cols)
}

# %%
library(dplyr)

# Fill demographics

columns = do.call(c, list(
    column_group_index("00 Demographics"),
    column_group_index("11 Daily Internet Usage"),
    column_group_index("12 Frequency of Online Purchases"),
    column_group_index("13 Money Spent for Online Purchases"),
    column_group_index("14 Social Media Usage")
))

cat("Cols:", columns)

df <- df %>%
  mutate(trial = (row_number() - 1) %/% 3) %>%
  group_by(trial) %>%
  mutate(across(all_of(columns), ~ first(.))) %>%
  ungroup() %>%
  select(-trial)

df$SceIdx  <- as.integer(sub(".*-",  "", df$Tri))
df$Tri <- as.integer(sub("-.*", "", df$Tri))

df
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# Cols: 001 002 003 004 005 006 007 008 009
#    Tri Sce                    001 002 003 004 005 006 007 008 ⋯ 030 031 032 033
# 1   0  Disadvantaged Customer b   55  a   c   d   c   c   g   ⋯ 6   4   5   6
# 2   0  Same Price             b   55  a   c   d   c   c   g   ⋯ 5   4   5   6
# 3   0  Favored Customer       b   55  a   c   d   c   c   g   ⋯ 4   5   4   4
# 4   1  Disadvantaged Customer b   63  e   a   f   e   d   g   ⋯ 6   7   4   5
# 5   1  Favored Customer       b   63  e   a   f   e   d   g   ⋯ 6   7   5   6
# 6   1  Same Price             b   63  e   a   f   e   d   g   ⋯ 4   6   3   2
# 7  10  Same Price             b   62  d   a   d   c   f   g   ⋯ 3   6   2   4
# 8  10  Favored Customer       b   62  d   a   d   c   f   g   ⋯ 5   6   4   4
# 9  10  Disadvantaged Customer b   62  d   a   d   c   f   g   ⋯ 5   6   4   4
# 10 11  Same Price             b   58  a   c   e   c   f   g   ⋯ 4   6   5   4
# 11 11  Favored Customer       b   58  a   c   e   c   f   g   ⋯ 4   6   3   4
# 12 11  Disadvantaged Customer b   58  a   c   e   c   f   g   ⋯ 3   6   3   4
# 13 12  Favored Customer       b   52  a   a   d   e   f   g   ⋯ 3   6   5   2
# 14 12  Disadvantaged Customer b   52  a   a   d   e   f   g   ⋯ 4   6   4   5
# 15 12  Same Price             b   52  a   a   d   e   f   g   ⋯ 4   6   3   4
# 16 13  Same Price             a   53  d   a   d   c   b   d   ⋯ 5   6   4   6
# 17 13  Favored Customer       a   53  d   a   d   c   b   d   ⋯ 5   6   4   5
# 18 13  Disadvantaged Customer a   53  d   a   d   c   b   d   ⋯ 5   6   2   3
# 19 14  Favored Customer       b   53  d   a   e   c   f   g   ⋯ 3   2   4   6
# 20 14  Same Price             b   53  d   a   e   c   f   g   ⋯ 5   6   4   5
# 21 14  Disadvantaged Customer b   53  d   a   e   c   f   g   ⋯ 5   6   4   5
# 22  2  Same Price             b   62  d   a   e   c   f   g   ⋯ 5   6   2   3
# 23  2  Disadvantaged Customer b   62  d   a   e   c   f   g   ⋯ 5   4   4   3
# 24  2  Favored Customer       b   62  d   a   e   c   f   g   ⋯ 5   6   3   4
# 25  3  Disadvantaged Customer b   42  e   a   c   c   e   g   ⋯ 3   4   3   4
# 26  3  Same Price             b   42  e   a   c   c   e   g   ⋯ 3   4   3   4
# 27  3  Favored Customer       b   42  e   a   c   c   e   g   ⋯ 5   6   4   5
# 28  4  Same Price             a   62  a   a   d   d   f   e   ⋯ 3   6   4   5
# 29  4  Disadvantaged Customer a   62  a   a   d   d   f   e   ⋯ 4   6   4   5
# 30  4  Favored Customer       a   62  a   a   d   d   f   e   ⋯ 5   6   3   4
# 31  5  Same Price             b   62  d   c   d   d   f   g   ⋯ 5   7   4   6
# 32  5  Disadvantaged Customer b   62  d   c   d   d   f   g   ⋯ 5   6   4   6
# 33  5  Favored Customer       b   62  d   c   d   d   f   g   ⋯ 4   6   3   4
# 34  6  Disadvantaged Customer b   42  b   e   c   c   f   c   ⋯ 4   6   4   5
# 35  6  Same Price             b   42  b   e   c   c   f   c   ⋯ 5   6   4   5
# 36  6  Favored Customer       b   42  b   e   c   c   f   c   ⋯ 4   5   3   5
# 37  7  Same Price             b   42  e   a   f   c   f   g   ⋯ 2   4   2   2
# 38  7  Favored Customer       b   42  e   a   f   c   f   g   ⋯ 3   4   3   2
# 39  7  Disadvantaged Customer b   42  e   a   f   c   f   g   ⋯ 3   5   4   3
# 40  8  Same Price             b   65  d   a   d   c   e   g   ⋯ 6   3   4   6
# 41  8  Disadvantaged Customer b   65  d   a   d   c   e   g   ⋯ 5   6   3   3
# 42  8  Favored Customer       b   65  d   a   d   c   e   g   ⋯ 5   6   3   6
# 43  9  Favored Customer       b   62  e   a   d   c   f   g   ⋯ 4   6   5   6
# 44  9  Disadvantaged Customer b   62  e   a   d   c   f   g   ⋯ 4   6   5   6
# 45  9  Same Price             b   62  e   a   d   c   f   g   ⋯ 4   6   5   6
#    034 035 036 037 038 SceIdx
# 1  6   7   a   6   6   1
# 2  6   5   a   4   6   2
# 3  4   5   b   6   6   3
# 4  6   6   a   6   4   1
# 5  6   5   a   6   6   2
# 6  5   5   b   6   6   3
# 7  5   6   b   6   4   1
# 8  5   6   b   4   4   2
# 9  5   5   b   3   5   3
# 10 3   6   b   6   6   1
# 11 3   6   b   6   6   2
# 12 4   6   a   6   5   3
# 13 4   6   c   6   6   1
# 14 3   6   a   6   6   2
# 15 2   6   b   6   6   3
# 16 5   4   b   6   6   1
# 17 6   5   b   6   6   2
# 18 4   6   b   6   6   3
# 19 4   6   c   6   6   1
# 20 4   6   b   6   6   2
# 21 4   6   a   6   6   3
# 22 4   5   b   6   6   1
# 23 2   5   b   6   6   2
# 24 5   6   b   6   5   3
# 25 2   6   a   6   6   1
# 26 2   5   b   6   6   2
# 27 4   6   b   6   6   3
# 28 3   6   b   6   5   1
# 29 4   6   b   6   4   2
# 30 2   6   b   6   6   3
# 31 5   6   b   6   7   1
# 32 5   6   b   6   7   2
# 33 3   6   b   6   5   3
# 34 5   5   a   6   5   1
# 35 6   5   a   6   5   2
# 36 5   6   b   6   5   3
# 37 3   5   b   6   5   1
# 38 4   6   b   6   5   2
# 39 4   6   a   4   6   3
# 40 5   6   b   6   6   1
# 41 5   6   b   6   4   2
# 42 3   6   b   3   6   3
# 43 5   6   c   6   6   1
# 44 5   6   a   6   6   2
# 45 5   6   b   6   6   3

# %%
df$price_fairness <- rowMeans(sapply(column_group_index("01 Distributive Price Fairness Perception"), function(col) as.integer(df[[col]])))
df$purchase_intention <- rowMeans(sapply(column_group_index("03 Purchase Intention"), function(col) as.integer(df[[col]])))
df$future_search_intention <- rowMeans(sapply(column_group_index("04 Future Search Intention"), function(col) as.integer(df[[col]])))
df$product_involvement <- rowMeans(sapply(column_group_index("08 Product Involvement"), function(col) as.integer(df[[col]])))
df$perceived_information <- rowMeans(sapply(column_group_index("18 Perceived Information Sensitivity"), function(col) as.integer(df[[col]])))
df$willingness_reveal <- rowMeans(sapply(column_group_index("19 Willingness to Reveal Information"), function(col) as.integer(df[[col]])))
df
# Out:
#    Tri Sce                    001 002 003 004 005 006 007 008 ⋯ 036 037 038
# 1   0  Disadvantaged Customer b   55  a   c   d   c   c   g   ⋯ a   6   6
# 2   0  Same Price             b   55  a   c   d   c   c   g   ⋯ a   4   6
# 3   0  Favored Customer       b   55  a   c   d   c   c   g   ⋯ b   6   6
# 4   1  Disadvantaged Customer b   63  e   a   f   e   d   g   ⋯ a   6   4
# 5   1  Favored Customer       b   63  e   a   f   e   d   g   ⋯ a   6   6
# 6   1  Same Price             b   63  e   a   f   e   d   g   ⋯ b   6   6
# 7  10  Same Price             b   62  d   a   d   c   f   g   ⋯ b   6   4
# 8  10  Favored Customer       b   62  d   a   d   c   f   g   ⋯ b   4   4
# 9  10  Disadvantaged Customer b   62  d   a   d   c   f   g   ⋯ b   3   5
# 10 11  Same Price             b   58  a   c   e   c   f   g   ⋯ b   6   6
# 11 11  Favored Customer       b   58  a   c   e   c   f   g   ⋯ b   6   6
# 12 11  Disadvantaged Customer b   58  a   c   e   c   f   g   ⋯ a   6   5
# 13 12  Favored Customer       b   52  a   a   d   e   f   g   ⋯ c   6   6
# 14 12  Disadvantaged Customer b   52  a   a   d   e   f   g   ⋯ a   6   6
# 15 12  Same Price             b   52  a   a   d   e   f   g   ⋯ b   6   6
# 16 13  Same Price             a   53  d   a   d   c   b   d   ⋯ b   6   6
# 17 13  Favored Customer       a   53  d   a   d   c   b   d   ⋯ b   6   6
# 18 13  Disadvantaged Customer a   53  d   a   d   c   b   d   ⋯ b   6   6
# 19 14  Favored Customer       b   53  d   a   e   c   f   g   ⋯ c   6   6
# 20 14  Same Price             b   53  d   a   e   c   f   g   ⋯ b   6   6
# 21 14  Disadvantaged Customer b   53  d   a   e   c   f   g   ⋯ a   6   6
# 22  2  Same Price             b   62  d   a   e   c   f   g   ⋯ b   6   6
# 23  2  Disadvantaged Customer b   62  d   a   e   c   f   g   ⋯ b   6   6
# 24  2  Favored Customer       b   62  d   a   e   c   f   g   ⋯ b   6   5
# 25  3  Disadvantaged Customer b   42  e   a   c   c   e   g   ⋯ a   6   6
# 26  3  Same Price             b   42  e   a   c   c   e   g   ⋯ b   6   6
# 27  3  Favored Customer       b   42  e   a   c   c   e   g   ⋯ b   6   6
# 28  4  Same Price             a   62  a   a   d   d   f   e   ⋯ b   6   5
# 29  4  Disadvantaged Customer a   62  a   a   d   d   f   e   ⋯ b   6   4
# 30  4  Favored Customer       a   62  a   a   d   d   f   e   ⋯ b   6   6
# 31  5  Same Price             b   62  d   c   d   d   f   g   ⋯ b   6   7
# 32  5  Disadvantaged Customer b   62  d   c   d   d   f   g   ⋯ b   6   7
# 33  5  Favored Customer       b   62  d   c   d   d   f   g   ⋯ b   6   5
# 34  6  Disadvantaged Customer b   42  b   e   c   c   f   c   ⋯ a   6   5
# 35  6  Same Price             b   42  b   e   c   c   f   c   ⋯ a   6   5
# 36  6  Favored Customer       b   42  b   e   c   c   f   c   ⋯ b   6   5
# 37  7  Same Price             b   42  e   a   f   c   f   g   ⋯ b   6   5
# 38  7  Favored Customer       b   42  e   a   f   c   f   g   ⋯ b   6   5
# 39  7  Disadvantaged Customer b   42  e   a   f   c   f   g   ⋯ a   4   6
# 40  8  Same Price             b   65  d   a   d   c   e   g   ⋯ b   6   6
# 41  8  Disadvantaged Customer b   65  d   a   d   c   e   g   ⋯ b   6   4
# 42  8  Favored Customer       b   65  d   a   d   c   e   g   ⋯ b   3   6
# 43  9  Favored Customer       b   62  e   a   d   c   f   g   ⋯ c   6   6
# 44  9  Disadvantaged Customer b   62  e   a   d   c   f   g   ⋯ a   6   6
# 45  9  Same Price             b   62  e   a   d   c   f   g   ⋯ b   6   6
#    SceIdx price_fairness purchase_intention future_search_intention
# 1  1      4.333333       5.666667           6.000000
# 2  2      5.666667       6.000000           5.666667
# 3  3      3.666667       3.333333           5.666667
# 4  1      4.000000       4.666667           6.666667
# 5  2      5.666667       4.666667           6.333333
# 6  3      5.666667       5.666667           5.666667
# 7  1      4.666667       5.666667           5.666667
# 8  2      4.000000       3.333333           6.333333
# 9  3      4.000000       2.666667           6.000000
# 10 1      4.666667       5.666667           3.333333
# 11 2      4.333333       5.000000           4.000000
# 12 3      4.666667       3.333333           4.666667
# 13 1      3.666667       5.666667           5.000000
# 14 2      5.666667       5.666667           6.000000
# 15 3      5.333333       6.000000           5.333333
# 16 1      5.000000       6.333333           4.000000
# 17 2      4.000000       5.000000           5.000000
# 18 3      3.333333       5.333333           5.666667
# 19 1      4.000000       5.000000           5.666667
# 20 2      4.000000       6.000000           5.000000
# 21 3      5.333333       5.333333           4.333333
# 22 1      6.000000       6.333333           5.666667
# 23 2      5.666667       4.333333           5.666667
# 24 3      3.666667       5.000000           6.000000
# 25 1      4.333333       5.333333           5.333333
# 26 2      5.666667       5.666667           6.000000
# 27 3      5.333333       5.000000           5.666667
# 28 1      6.000000       6.333333           4.666667
# 29 2      5.000000       4.000000           5.666667
# 30 3      4.666667       3.000000           6.333333
# 31 1      4.333333       6.000000           5.333333
# 32 2      4.000000       4.666667           5.666667
# 33 3      5.000000       3.333333           6.000000
# 34 1      5.000000       5.666667           5.000000
# 35 2      5.000000       5.666667           4.000000
# 36 3      4.000000       4.000000           5.000000
# 37 1      4.333333       6.333333           5.000000
# 38 2      5.000000       5.000000           5.666667
# 39 3      4.666667       4.000000           6.666667
# 40 1      4.000000       4.666667           6.000000
# 41 2      5.666667       4.666667           6.000000
# 42 3      4.000000       4.333333           5.666667
# 43 1      3.666667       6.000000           5.333333
# 44 2      5.000000       5.333333           5.000000
# 45 3      4.333333       5.666667           4.000000
#    product_involvement perceived_information willingness_reveal
# 1  5.857143            4.8                   2.4
# 2  5.285714            1.8                   1.8
# 3  4.428571            2.4                   2.6
# 4  5.571429            5.2                   2.6
# 5  5.857143            5.2                   3.0
# 6  4.428571            2.8                   3.4
# 7  4.285714            5.8                   3.8
# 8  5.000000            4.0                   4.2
# 9  4.857143            4.4                   4.0
# 10 4.857143            5.6                   3.8
# 11 4.571429            4.4                   2.8
# 12 4.571429            4.4                   1.8
# 13 4.571429            4.8                   3.0
# 14 4.857143            2.8                   3.0
# 15 4.428571            2.8                   3.2
# 16 5.142857            4.0                   4.6
# 17 5.285714            4.4                   2.6
# 18 4.571429            4.2                   2.4
# 19 4.571429            4.8                   4.2
# 20 5.142857            2.2                   1.8
# 21 5.142857            4.4                   2.4
# 22 4.142857            4.4                   2.8
# 23 4.142857            5.2                   2.8
# 24 5.000000            4.2                   3.0
# 25 3.857143            5.6                   2.0
# 26 3.714286            2.2                   2.4
# 27 5.142857            4.2                   2.8
# 28 4.714286            4.0                   3.0
# 29 5.000000            4.8                   3.6
# 30 4.285714            4.4                   2.2
# 31 5.571429            5.0                   3.8
# 32 5.428571            6.0                   3.0
# 33 4.571429            4.4                   2.4
# 34 5.000000            4.8                   3.2
# 35 5.285714            4.2                   3.6
# 36 4.857143            4.0                   3.2
# 37 3.428571            4.6                   3.4
# 38 4.000000            4.6                   3.0
# 39 4.428571            4.0                   2.4
# 40 5.000000            5.6                   2.8
# 41 4.857143            2.6                   3.0
# 42 5.000000            5.8                   3.2
# 43 5.428571            4.0                   3.8
# 44 5.428571            3.8                   3.6
# 45 5.428571            2.6                   2.2

# %%
variablen <- c("price_fairness", "purchase_intention", "future_search_intention", "product_involvement")
n <- length(variablen)

cor_matrix <- matrix("", nrow = n, ncol = n, dimnames = list(variablen, variablen))
p_values <- matrix(NA, nrow = n, ncol = n, dimnames = list(variablen, variablen))

for (i in seq_along(variablen)) {
  for (j in seq_along(variablen)) {
    if (i == j) {
      cor_matrix[i, j] <- "1.000"
    } else {
      test <- cor.test(df[[variablen[i]]], df[[variablen[j]]])
      r <- test$estimate
      p <- test$p.value
      stars <- if (p < 0.01) {
        "***"
      } else if (p < 0.05) {
        "**"
      } else if (p < 0.10) {
        "*"
      } else {
        ""
      }
      cor_matrix[i, j] <- sprintf("%.3f%s", r, stars)
      p_values[i, j] <- p
    }
  }
}

means <- round(colMeans(df[variablen], na.rm = TRUE), 2)
stds <- round(apply(df[variablen], 2, sd, na.rm = TRUE), 2)

cor_matrix <- rbind(cor_matrix, Mean = as.character(means), `Standard Deviation` = as.character(stds))
cor_matrix
# Out:
#                         price_fairness purchase_intention
# price_fairness          1.000          0.374***
# purchase_intention      0.374***       1.000
# future_search_intention -0.204*        -0.361***
# product_involvement     0.194*         0.088
# Mean                    4.66           5.14
# Standard Deviation      0.73           1.03
#                         future_search_intention product_involvement
# price_fairness          -0.204*                 0.194*
# purchase_intention      -0.361***               0.088
# future_search_intention 1.000                   0.071
# product_involvement     0.071                   1.000
# Mean                    5.82                    4.66
# Standard Deviation      0.57                    0.39

# %%
library(psych)

print("Cronbach's alpha")

categories <- c("01 Distributive Price Fairness Perception",
                "03 Purchase Intention",
                "04 Future Search Intention",
                "08 Product Involvement")

for (cat in categories) {
  cols <- column_group_index(cat)
  if (length(cols) == 0) next
  items <- df[, cols, drop = FALSE]
  alpha_val <- psych::alpha(items)$total$raw_alpha
  print(paste(cat, ":", alpha_val))
}
# Out:
# [1] "Cronbach's alpha"
# Warning message in psych::alpha(items):
# “Some items were negatively correlated with the first principal component and probably
# should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option”
# Some items ( 006 ) were negatively correlated with the first principal component and
# probably should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option[1] "01 Distributive Price Fairness Perception : 0.0845941151919868"
# [1] "03 Purchase Intention : 0.838731926966073"
# [1] "04 Future Search Intention : 0.584869431643626"
# Warning message in psych::alpha(items):
# “Some items were negatively correlated with the first principal component and probably
# should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option”
# Some items ( 019 020 ) were negatively correlated with the first principal component and
# probably should be reversed.
# To do this, run the function again with the 'check.keys=TRUE' option[1] "08 Product Involvement : 0.0121484212742469"

# %%
df$age <- df[["002"]]
df$gender <- df[["001"]]
df$dummy_gender <- as.integer(df$gender == "b")
df$income <- df[["005"]]
df$dummy_income <- as.integer(df$income %in% c("d", "e", "f"))
df$frequency <- df[[column_group_index("12 Frequency of Online Purchases")[1]]]
df$dummy_frequency <- as.integer(df$frequency == "f")
df$favored <- as.integer(df$Sce == "Favored Customer")
df$disadvantaged <- as.integer(df$Sce == "Disadvantaged Customer")
df$scenario <- ifelse(df$Sce == "Favored Customer", 1,
               ifelse(df$Sce == "Disadvantaged Customer", 2, 0))
df$education = df[["003"]]
df$employment = df[["004"]]
df$social_media_usage = df[[column_group_index("14 Social Media Usage")[1]]]

df$internet_usage = df[[column_group_index("11 Daily Internet Usage")[1]]]
df$money_spent = df[[column_group_index("13 Money Spent for Online Purchases")[1]]]

df$is_device_used = df[["010"]]
df$is_geographical_location = df[["011"]]
df$is_past_browsing_behavior = df[["012"]]
df$is_past_shopping_behavior = df[["013"]]
df$is_social_media_data = df[["014"]]

df$wr_device_used = df[["015"]]
df$wr_geographical_location = df[["016"]]
df$wr_past_browsing_behavior = df[["017"]]
df$wr_past_shopping_behavior = df[["018"]]
df$wr_social_media_data = df[["019"]]


df
# Out:
#    Tri Sce                    001 002 003 004 005 006 007 008 ⋯ is_device_used
# 1   0  Disadvantaged Customer b   37  d   a   c   5   4   6   ⋯ 5
# 2   0  Same Price             b   37  d   a   c   6   7   6   ⋯ 6
# 3   0  Favored Customer       b   37  d   a   c   5   3   5   ⋯ 6
# 4   1  Disadvantaged Customer b   57  d   a   e   4   6   6   ⋯ 5
# 5   1  Favored Customer       b   57  d   a   e   4   4   5   ⋯ 5
# 6   1  Same Price             b   57  d   a   e   6   4   5   ⋯ 5
# 7  10  Same Price             a   62  c   a   d   6   4   5   ⋯ 6
# 8  10  Favored Customer       a   62  c   a   d   3   2   4   ⋯ 4
# 9  10  Disadvantaged Customer a   62  c   a   d   4   6   6   ⋯ 6
# 10 11  Same Price             a   42  d   c   e   5   6   4   ⋯ 6
# 11 11  Favored Customer       a   42  d   c   e   5   6   4   ⋯ 2
# 12 11  Disadvantaged Customer a   42  d   c   e   5   3   6   ⋯ 4
# 13 12  Favored Customer       a   42  a   a   f   4   5   6   ⋯ 4
# 14 12  Disadvantaged Customer a   42  a   a   f   6   5   6   ⋯ 5
# 15 12  Same Price             a   42  a   a   f   5   6   6   ⋯ 6
# 16 13  Same Price             b   42  d   a   f   5   6   4   ⋯ 5
# 17 13  Favored Customer       b   42  d   a   f   2   3   4   ⋯ 5
# 18 13  Disadvantaged Customer b   42  d   a   f   5   4   3   ⋯ 2
# 19 14  Favored Customer       b   43  c   d   d   4   3   6   ⋯ 4
# 20 14  Same Price             b   43  c   d   d   6   4   3   ⋯ 6
# 21 14  Disadvantaged Customer b   43  c   d   d   6   6   5   ⋯ 4
# 22 15  Disadvantaged Customer b   42  e   e   c   6   3   5   ⋯ 4
# 23 15  Favored Customer       b   42  e   e   c   4   6   5   ⋯ 5
# 24 15  Same Price             b   42  e   e   c   4   6   6   ⋯ 6
# 25 16  Disadvantaged Customer a   35  c   a   c   5   6   6   ⋯ 6
# 26 16  Same Price             a   35  c   a   c   6   6   6   ⋯ 6
# 27 16  Favored Customer       a   35  c   a   c   3   6   4   ⋯ 5
# 28 17  Disadvantaged Customer a   68  e   c   f   4   5   6   ⋯ 6
# 29 17  Same Price             a   68  e   c   f   6   5   6   ⋯ 5
# 30 17  Favored Customer       a   68  e   c   f   4   5   4   ⋯ 4
# ⋮  ⋮   ⋮                      ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋮   ⋱ ⋮
# 61 27  Favored Customer       b   38  d   a   e   5   2   4   ⋯ 6
# 62 27  Disadvantaged Customer b   38  d   a   e   4   3   6   ⋯ 7
# 63 27  Same Price             b   38  d   a   e   5   6   2   ⋯ 7
# 64 28  Same Price             a   42  e   f   e   6   5   4   ⋯ 7
# 65 28  Disadvantaged Customer a   42  e   f   e   3   6   5   ⋯ 6
# 66 28  Favored Customer       a   42  e   f   e   5   4   3   ⋯ 4
# 67 29  Same Price             b   52  e   c   d   4   5   6   ⋯ 6
# 68 29  Favored Customer       b   52  e   c   d   5   2   3   ⋯ 4
# 69 29  Disadvantaged Customer b   52  e   c   d   6   5   4   ⋯ 5
# 70  3  Disadvantaged Customer b   32  d   a   f   3   5   6   ⋯ 6
# 71  3  Same Price             b   32  d   a   f   6   5   6   ⋯ 5
# 72  3  Favored Customer       b   32  d   a   f   6   5   6   ⋯ 4
# 73  4  Same Price             b   62  d   b   d   4   5   6   ⋯ 6
# 74  4  Disadvantaged Customer b   62  d   b   d   5   4   3   ⋯ 5
# 75  4  Favored Customer       b   62  d   b   d   3   5   6   ⋯ 5
# 76  5  Same Price             a   55  e   a   f   6   5   5   ⋯ 6
# 77  5  Disadvantaged Customer a   55  e   a   f   3   2   4   ⋯ 2
# 78  5  Favored Customer       a   55  e   a   f   6   4   3   ⋯ 4
# 79  6  Disadvantaged Customer b   58  g   a   d   6   4   5   ⋯ 4
# 80  6  Same Price             b   58  g   a   d   2   3   5   ⋯ 5
# 81  6  Favored Customer       b   58  g   a   d   3   6   5   ⋯ 4
# 82  7  Same Price             b   42  d   d   d   6   5   3   ⋯ 5
# 83  7  Favored Customer       b   42  d   d   d   4   3   5   ⋯ 3
# 84  7  Disadvantaged Customer b   42  d   d   d   6   5   4   ⋯ 3
# 85  8  Same Price             b   42  d   a   d   6   5   5   ⋯ 6
# 86  8  Disadvantaged Customer b   42  d   a   d   6   3   2   ⋯ 5
# 87  8  Favored Customer       b   42  d   a   d   5   2   4   ⋯ 6
# 88  9  Favored Customer       b   62  e   a   f   4   3   6   ⋯ 6
# 89  9  Disadvantaged Customer b   62  e   a   f   6   5   4   ⋯ 6
# 90  9  Same Price             b   62  e   a   f   6   5   4   ⋯ 6
#    is_geographical_location is_past_browsing_behavior is_past_shopping_behavior
# 1  5                        6                         6
# 2  7                        5                         6
# 3  6                        4                         6
# 4  6                        6                         6
# 5  6                        5                         6
# 6  6                        6                         6
# 7  6                        5                         6
# 8  3                        6                         6
# 9  6                        3                         6
# 10 7                        5                         6
# 11 4                        6                         7
# 12 3                        6                         7
# 13 6                        6                         6
# 14 6                        6                         7
# 15 4                        6                         6
# 16 6                        6                         6
# 17 4                        5                         6
# 18 3                        6                         7
# 19 6                        6                         7
# 20 7                        4                         6
# 21 5                        6                         6
# 22 3                        6                         7
# 23 6                        6                         6
# 24 6                        3                         5
# 25 6                        5                         6
# 26 6                        5                         3
# 27 6                        6                         7
# 28 5                        6                         6
# 29 6                        6                         6
# 30 5                        6                         6
# ⋮  ⋮                        ⋮                         ⋮
# 61 5                        7                         6
# 62 7                        5                         6
# 63 6                        5                         6
# 64 6                        4                         6
# 65 6                        6                         6
# 66 4                        6                         6
# 67 6                        4                         5
# 68 4                        6                         6
# 69 6                        6                         5
# 70 5                        6                         6
# 71 6                        5                         6
# 72 4                        6                         7
# 73 6                        6                         6
# 74 6                        6                         6
# 75 6                        6                         7
# 76 6                        6                         6
# 77 3                        6                         6
# 78 6                        6                         6
# 79 6                        6                         6
# 80 6                        6                         6
# 81 4                        6                         6
# 82 6                        6                         7
# 83 4                        6                         6
# 84 3                        7                         6
# 85 5                        4                         6
# 86 5                        6                         5
# 87 4                        6                         6
# 88 6                        6                         7
# 89 6                        6                         7
# 90 6                        6                         5
#    is_social_media_data wr_device_used wr_geographical_location
# 1  7                    6              5
# 2  5                    5              4
# 3  5                    5              4
# 4  6                    5              6
# 5  6                    4              4
# 6  7                    6              4
# 7  6                    5              6
# 8  6                    6              4
# 9  6                    6              4
# 10 4                    5              3
# 11 6                    4              6
# 12 6                    4              6
# 13 7                    6              5
# 14 7                    7              2
# 15 6                    6              3
# 16 7                    6              5
# 17 6                    4              6
# 18 6                    6              4
# 19 6                    4              6
# 20 6                    5              4
# 21 7                    6              6
# 22 6                    3              5
# 23 6                    4              2
# 24 4                    6              5
# 25 6                    7              6
# 26 2                    5              4
# 27 6                    5              4
# 28 7                    6              4
# 29 4                    6              5
# 30 4                    6              4
# ⋮  ⋮                    ⋮              ⋮
# 61 6                    3              6
# 62 4                    5              2
# 63 4                    5              3
# 64 6                    5              4
# 65 6                    5              5
# 66 6                    6              5
# 67 6                    5              4
# 68 7                    6              2
# 69 6                    6              4
# 70 6                    4              6
# 71 4                    6              5
# 72 6                    6              5
# 73 6                    6              5
# 74 7                    6              5
# 75 6                    4              6
# 76 5                    4              5
# 77 6                    5              4
# 78 5                    6              2
# 79 6                    5              6
# 80 5                    6              4
# 81 6                    6              6
# 82 7                    6              5
# 83 7                    6              6
# 84 6                    5              3
# 85 5                    6              5
# 86 6                    5              4
# 87 5                    5              3
# 88 7                    6              6
# 89 7                    6              5
# 90 6                    5              6
#    wr_past_browsing_behavior wr_past_shopping_behavior wr_social_media_data
# 1  4                         3                         2
# 2  6                         5                         3
# 3  6                         3                         4
# 4  5                         4                         4
# 5  6                         3                         4
# 6  6                         5                         5
# 7  7                         3                         4
# 8  6                         3                         2
# 9  6                         4                         5
# 10 6                         4                         5
# 11 6                         4                         5
# 12 5                         4                         3
# 13 6                         6                         4
# 14 6                         4                         3
# 15 6                         3                         4
# 16 7                         4                         5
# 17 6                         4                         5
# 18 6                         4                         3
# 19 5                         3                         4
# 20 6                         5                         6
# 21 7                         5                         3
# 22 7                         4                         5
# 23 6                         2                         4
# 24 6                         4                         6
# 25 7                         3                         4
# 26 5                         3                         6
# 27 6                         4                         3
# 28 6                         4                         3
# 29 4                         3                         2
# 30 6                         3                         2
# ⋮  ⋮                         ⋮                         ⋮
# 61 3                         4                         6
# 62 6                         4                         6
# 63 6                         4                         6
# 64 6                         3                         4
# 65 6                         4                         4
# 66 5                         5                         4
# 67 6                         3                         5
# 68 7                         5                         3
# 69 5                         3                         4
# 70 4                         3                         4
# 71 6                         3                         4
# 72 6                         3                         4
# 73 6                         4                         2
# 74 6                         4                         5
# 75 6                         4                         5
# 76 6                         4                         6
# 77 6                         3                         4
# 78 4                         5                         5
# 79 6                         4                         6
# 80 4                         3                         4
# 81 5                         5                         4
# 82 7                         4                         3
# 83 6                         3                         4
# 84 6                         4                         3
# 85 4                         3                         6
# 86 6                         2                         6
# 87 6                         2                         4
# 88 7                         4                         3
# 89 6                         3                         4
# 90 7                         4                         6

# %%
process(data = df,
        model = 4,
        y = "purchase_intention", 
        x = "scenario",
        mcx = 1,
        m = "price_fairness",
        cov = c("age", "dummy_gender", "dummy_income", "dummy_frequency"),
        boot = 100,
        seed = 654321)
# Out:
# ********************* PROCESS for R Version 4.3.1 *********************
#
#            Written by Andrew F. Hayes, Ph.D.  www.afhayes.com
#    Documentation available in Hayes (2022). www.guilford.com/p/hayes3
#
# ***********************************************************************
#
# Model : 4
#     Y : purchase_intention
#     X : scenario
#     M : price_fairness
#
# Covariates:
#        age dummy_gender dummy_income dummy_frequency
#
# Sample size: 90
#
# Custom seed: 654321
#
# Coding of categorical X variable for analysis:
#    scenario        X1        X2
#      0.0000    0.0000    0.0000
#      1.0000    1.0000    0.0000
#      2.0000    0.0000    1.0000
#
# ***********************************************************************
# Outcome Variable: price_fairness
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.5717    0.3268    0.3839    6.7152    6.0000   83.0000    0.0000
#
# Model:
#                     coeff        se         t         p      LLCI      ULCI
# constant           5.2791    0.4191   12.5963    0.0000    4.4455    6.1127
# X1                -0.8556    0.1600   -5.3481    0.0000   -1.1737   -0.5374
# X2                -0.4333    0.1600   -2.7088    0.0082   -0.7515   -0.1152
# age                0.0051    0.0072    0.7104    0.4794   -0.0093    0.0195
# dummy_gender      -0.1399    0.1433   -0.9761    0.3318   -0.4249    0.1451
# dummy_income      -0.5882    0.2350   -2.5037    0.0142   -1.0556   -0.1209
# dummy_frequency    0.2336    0.1685    1.3866    0.1693   -0.1015    0.5686
#
# ***********************************************************************
# Outcome Variable: purchase_intention
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.6149    0.3781    0.7195    7.1219    7.0000   82.0000    0.0000
#
# Model:
#                     coeff        se         t         p      LLCI      ULCI
# constant           5.2168    0.9790    5.3285    0.0000    3.2692    7.1645
# X1                -1.2518    0.2540   -4.9292    0.0000   -1.7570   -0.7466
# X2                -0.9805    0.2285   -4.2913    0.0000   -1.4350   -0.5260
# price_fairness     0.1732    0.1503    1.1527    0.2524   -0.1257    0.4722
# age                0.0106    0.0099    1.0714    0.2871   -0.0091    0.0304
# dummy_gender       0.0021    0.1973    0.0104    0.9917   -0.3904    0.3945
# dummy_income      -0.4627    0.3336   -1.3870    0.1692   -1.1263    0.2009
# dummy_frequency   -0.2954    0.2333   -1.2664    0.2090   -0.7595    0.1686
#
# ***********************************************************************
# Bootstrapping progress:
#   |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>| 100%
#
# **************** DIRECT AND INDIRECT EFFECTS OF X ON Y ****************
#
# Relative direct effects of X on Y:
#       effect        se         t         p      LLCI      ULCI
# X1   -1.2518    0.2540   -4.9292    0.0000   -1.7570   -0.7466
# X2   -0.9805    0.2285   -4.2913    0.0000   -1.4350   -0.5260
#
# Omnibus test of direct effect of X on Y:
#     R2-chng         F       df1       df2         p
#      0.2105   13.8755    2.0000   82.0000    0.0000
#
# ----------
#
# Relative indirect effects of X on Y:
#
# scenario    ->    price_fairness    ->    purchase_intention
#
#       Effect    BootSE  BootLLCI  BootULCI
# X1   -0.1482    0.1579   -0.4787    0.1455
# X2   -0.0751    0.0902   -0.2842    0.0743
#
# ******************** ANALYSIS NOTES AND ERRORS ************************
#
# Level of confidence for all confidence intervals in output: 95
#
# Number of bootstraps for percentile bootstrap confidence intervals: 5000

# %%
process(data = df,
        model = 4,
        y = "future_search_intention", 
        x = "scenario",
        mcx = 1,
        m = "price_fairness",
        cov = c("age", "dummy_gender", "dummy_income", "dummy_frequency"),
        boot = 100,
        seed = 654321)
# Out:
# ********************* PROCESS for R Version 4.3.1 *********************
#
#            Written by Andrew F. Hayes, Ph.D.  www.afhayes.com
#    Documentation available in Hayes (2022). www.guilford.com/p/hayes3
#
# ***********************************************************************
#
# Model : 4
#     Y : future_search_intention
#     X : scenario
#     M : price_fairness
#
# Covariates:
#        age dummy_gender dummy_income dummy_frequency
#
# Sample size: 90
#
# Custom seed: 654321
#
# Coding of categorical X variable for analysis:
#    scenario        X1        X2
#      0.0000    0.0000    0.0000
#      1.0000    1.0000    0.0000
#      2.0000    0.0000    1.0000
#
# ***********************************************************************
# Outcome Variable: price_fairness
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.5717    0.3268    0.3839    6.7152    6.0000   83.0000    0.0000
#
# Model:
#                     coeff        se         t         p      LLCI      ULCI
# constant           5.2791    0.4191   12.5963    0.0000    4.4455    6.1127
# X1                -0.8556    0.1600   -5.3481    0.0000   -1.1737   -0.5374
# X2                -0.4333    0.1600   -2.7088    0.0082   -0.7515   -0.1152
# age                0.0051    0.0072    0.7104    0.4794   -0.0093    0.0195
# dummy_gender      -0.1399    0.1433   -0.9761    0.3318   -0.4249    0.1451
# dummy_income      -0.5882    0.2350   -2.5037    0.0142   -1.0556   -0.1209
# dummy_frequency    0.2336    0.1685    1.3866    0.1693   -0.1015    0.5686
#
# ***********************************************************************
# Outcome Variable: future_search_intention
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.5667    0.3212    0.2395    5.5425    7.0000   82.0000    0.0000
#
# Model:
#                     coeff        se         t         p      LLCI      ULCI
# constant           4.3962    0.5649    7.7824    0.0000    3.2725    5.5200
# X1                 0.6012    0.1465    4.1027    0.0001    0.3097    0.8927
# X2                 0.6009    0.1318    4.5579    0.0000    0.3386    0.8631
# price_fairness     0.0533    0.0867    0.6148    0.5404   -0.1192    0.2258
# age                0.0005    0.0057    0.0915    0.9273   -0.0109    0.0119
# dummy_gender       0.1399    0.1138    1.2293    0.2225   -0.0865    0.3664
# dummy_income       0.5684    0.1925    2.9530    0.0041    0.1855    0.9513
# dummy_frequency    0.1839    0.1346    1.3660    0.1757   -0.0839    0.4516
#
# ***********************************************************************
# Bootstrapping progress:
#   |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>| 100%
#
# **************** DIRECT AND INDIRECT EFFECTS OF X ON Y ****************
#
# Relative direct effects of X on Y:
#       effect        se         t         p      LLCI      ULCI
# X1    0.6012    0.1465    4.1027    0.0001    0.3097    0.8927
# X2    0.6009    0.1318    4.5579    0.0000    0.3386    0.8631
#
# Omnibus test of direct effect of X on Y:
#     R2-chng         F       df1       df2         p
#      0.2013   12.1559    2.0000   82.0000    0.0000
#
# ----------
#
# Relative indirect effects of X on Y:
#
# scenario    ->    price_fairness    ->    future_search_intention
#
#       Effect    BootSE  BootLLCI  BootULCI
# X1   -0.0456    0.0588   -0.1565    0.0769
# X2   -0.0231    0.0322   -0.0937    0.0379
#
# ******************** ANALYSIS NOTES AND ERRORS ************************
#
# Level of confidence for all confidence intervals in output: 95
#
# Number of bootstraps for percentile bootstrap confidence intervals: 5000

# %%
cat_list <- c("00 Demographics", 
              "11 Daily Internet Usage", 
              "12 Frequency of Online Purchases", 
              "13 Money Spent for Online Purchases", 
              "14 Social Media Usage")

freq_table <- data.frame()

for (cat in cat_list) {
  cols <- column_group_index(cat)
  valid_cols <- intersect(cols, names(df))
  if (length(valid_cols) == 0) next
  for (col in valid_cols) {
    if(!(col %in% c("002"))) {
        tbl <- table(df[[col]], useNA = "ifany")
        total <- sum(tbl)
        tmp <- data.frame(
          "Question" = cat,
          "Column"   = col,
          "Response" = names(tbl),
          "Absolute frequency" = as.numeric(tbl),
          "Relative frequency (in %)" = round(100 * as.numeric(tbl) / total, 2),
          check.names = FALSE,
          stringsAsFactors = FALSE
        )
        freq_table <- rbind(freq_table, tmp)
    }
  }
}

freq_table
# Out:
#    Question                            Column Response Absolute frequency
# 1  00 Demographics                     001    a        30
# 2  00 Demographics                     001    b        60
# 3  00 Demographics                     003    a         6
# 4  00 Demographics                     003    b         3
# 5  00 Demographics                     003    c        15
# 6  00 Demographics                     003    d        36
# 7  00 Demographics                     003    e        27
# 8  00 Demographics                     003    g         3
# 9  00 Demographics                     004    a        51
# 10 00 Demographics                     004    b         3
# 11 00 Demographics                     004    c        18
# 12 00 Demographics                     004    d         6
# 13 00 Demographics                     004    e         3
# 14 00 Demographics                     004    f         6
# 15 00 Demographics                     004    g         3
# 16 00 Demographics                     005    c         9
# 17 00 Demographics                     005    d        21
# 18 00 Demographics                     005    e        18
# 19 00 Demographics                     005    f        42
# 20 11 Daily Internet Usage             022    c        45
# 21 11 Daily Internet Usage             022    d        21
# 22 11 Daily Internet Usage             022    e        24
# 23 12 Frequency of Online Purchases    023    b         6
# 24 12 Frequency of Online Purchases    023    c         6
# 25 12 Frequency of Online Purchases    023    e         6
# 26 12 Frequency of Online Purchases    023    f        72
# 27 13 Money Spent for Online Purchases 024    c         3
# 28 13 Money Spent for Online Purchases 024    d         3
# 29 13 Money Spent for Online Purchases 024    e        12
# 30 13 Money Spent for Online Purchases 024    f        15
# 31 13 Money Spent for Online Purchases 024    g        57
# 32 14 Social Media Usage               025    a        78
# 33 14 Social Media Usage               025    b        12
#    Relative frequency (in %)
# 1  33.33
# 2  66.67
# 3   6.67
# 4   3.33
# 5  16.67
# 6  40.00
# 7  30.00
# 8   3.33
# 9  56.67
# 10  3.33
# 11 20.00
# 12  6.67
# 13  3.33
# 14  6.67
# 15  3.33
# 16 10.00
# 17 23.33
# 18 20.00
# 19 46.67
# 20 50.00
# 21 23.33
# 22 26.67
# 23  6.67
# 24  6.67
# 25  6.67
# 26 80.00
# 27  3.33
# 28  3.33
# 29 13.33
# 30 16.67
# 31 63.33
# 32 86.67
# 33 13.33

# %%
library(dplyr)

cat <- "17 Realism Check"
cols <- column_group_index(cat)

for (col in cols) {
  cat("ANOVA for:", col, "\n\n")
  
  # Descriptive statistics
  summary_df <- df %>%
    group_by(Sce) %>%
    summarize(
      M  = round(mean(.data[[col]], na.rm = TRUE), 2),
      SD = round(sd(.data[[col]], na.rm = TRUE), 2),
      n  = n()
    )
  print(summary_df)
  
  # One-way ANOVA
  fit <- aov(df[[col]] ~ Sce, data = df)
  print(summary(fit))
  
  cat("\n----------------------------------------\n\n")
}
# Out:
# ANOVA for: 027
#
# # A tibble: 3 × 4
#   Sce                        M    SD     n
#   <chr>                  <dbl> <dbl> <int>
# 1 Disadvantaged Customer  5.77  0.63    30
# 2 Favored Customer        5.57  0.73    30
# 3 Same Price              6.07  0.25    30
#             Df Sum Sq Mean Sq F value Pr(>F)
# Sce          2    3.8  1.9000    5.78 0.0044 **
# Residuals   87   28.6  0.3287
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ----------------------------------------
#
# ANOVA for: 028
#
# # A tibble: 3 × 4
#   Sce                        M    SD     n
#   <chr>                  <dbl> <dbl> <int>
# 1 Disadvantaged Customer  5.87  0.63    30
# 2 Favored Customer        5.53  0.78    30
# 3 Same Price              5.77  0.68    30
#             Df Sum Sq Mean Sq F value Pr(>F)
# Sce          2   1.76  0.8778   1.805  0.171
# Residuals   87  42.30  0.4862
#
# ----------------------------------------

# %%
vars <- c("gender", "education", "employment", "social_media_usage")

for (i in 1:length(vars)) { 
    for (j in 1:i) {
        if (i != j){
            cat("Chi-squared test for", vars[i], "vs", vars[j])
            tab <- table(df[[vars[i]]], df[[vars[j]]])
            print(tab)
            test <- chisq.test(tab)
            print(test)
        }
    }
}
# Out:
# Chi-squared test for education vs gender
#      a  b
#   a  3  3
#   b  0  3
#   c  9  6
#   d  6 30
#   e 12 15
#   g  0  3
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 14.55, df = 5, p-value = 0.01247
#
# Chi-squared test for employment vs gender
#      a  b
#   a 18 33
#   b  0  3
#   c  6 12
#   d  0  6
#   e  0  3
#   f  3  3
#   g  3  0
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 12.838, df = 6, p-value = 0.04568
#
# Chi-squared test for employment vs education
#      a  b  c  d  e  g
#   a  3  0  9 24 12  3
#   b  0  0  0  3  0  0
#   c  3  0  3  6  6  0
#   d  0  0  3  3  0  0
#   e  0  0  0  0  3  0
#   f  0  3  0  0  3  0
#   g  0  0  0  0  3  0
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 77.534, df = 30, p-value = 4.441e-06
#
# Chi-squared test for social_media_usage vs gender
#      a  b
#   a 24 54
#   b  6  6
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test with Yates' continuity correction
#
# data:  tab
# X-squared = 0.97356, df = 1, p-value = 0.3238
#
# Chi-squared test for social_media_usage vs education
#      a  b  c  d  e  g
#   a  6  3  6 36 24  3
#   b  0  0  9  0  3  0
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 35.769, df = 5, p-value = 1.056e-06
#
# Chi-squared test for social_media_usage vs employment
#      a  b  c  d  e  f  g
#   a 42  3 18  3  3  6  3
#   b  9  0  0  3  0  0  0
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 12.879, df = 6, p-value = 0.045

# %%
vars <- c("product_involvement", "age", "income", "internet_usage", "frequency", "money_spent")

for (var in vars) {
  cat("Kruskal-Wallis test for", var, "vs Sce\n")
  result <- kruskal.test(df[[var]] ~ df$Sce)
  print(result)
  cat("\n--------------------------------\n\n")
}
# Out:
# Kruskal-Wallis test for product_involvement vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 1.3904, df = 2, p-value = 0.499
#
#
# --------------------------------
#
# Kruskal-Wallis test for age vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------
#
# Kruskal-Wallis test for income vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------
#
# Kruskal-Wallis test for internet_usage vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------
#
# Kruskal-Wallis test for frequency vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------
#
# Kruskal-Wallis test for money_spent vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0, df = 2, p-value = 1
#
#
# --------------------------------

# %%
library(ez)
library(reshape2)
library(rstatix)

print("ANOVA: Price Fairness Perception")

df <- df %>%
  mutate(
    Tri = factor(Tri),
    Sce = factor(Sce)
  )

anova_results <- ezANOVA(
  data      = df,
  dv        = price_fairness,
  wid       = Tri,
  within    = Sce,
  detailed  = TRUE,
  type      = 3
)

print(anova_results$ANOVA)
print(anova_results$Mauchly)
print(anova_results$`Sphericity Corrections`)
# Out:
# [1] "ANOVA: Price Fairness Perception"
#        Effect DFn DFd        SSn      SSd          F            p p<.05
# 1 (Intercept)   1  29 1953.78272 15.62469 3626.29235 5.140624e-32     *
# 2         Sce   2  58   10.98025 20.72346   15.36554 4.417879e-06     *
#         ges
# 1 0.9817358
# 2 0.2320013
#   Effect         W         p p<.05
# 2    Sce 0.9775009 0.7271777
#   Effect      GGe        p[GG] p[GG]<.05      HFe        p[HF] p[HF]<.05
# 2    Sce 0.977996 5.429664e-06         * 1.047917 4.417879e-06         *

# %%
print("ANOVA: Purchase intention")

df <- df %>%
  mutate(
    Tri = factor(Tri),
    Sce = factor(Sce)
  )

anova_results <- ezANOVA(
  data      = df,
  dv        = purchase_intention,
  wid       = Tri,
  within    = Sce,
  detailed  = TRUE,
  type      = 3
)

print(anova_results$ANOVA)
print(anova_results$Mauchly)
print(anova_results$`Sphericity Corrections`)
# Out:
# [1] "ANOVA: Purchase intention"
#        Effect DFn DFd       SSn      SSd          F            p p<.05
# 1 (Intercept)   1  29 2375.0235 26.05062 2643.91740 4.816082e-30     *
# 2         Sce   2  58   31.9284 36.88642   25.10201 1.400723e-08     *
#         ges
# 1 0.9741846
# 2 0.3365651
#   Effect         W         p p<.05
# 2    Sce 0.9489359 0.4800831
#   Effect       GGe        p[GG] p[GG]<.05      HFe        p[HF] p[HF]<.05
# 2    Sce 0.9514168 2.883288e-08         * 1.016435 1.400723e-08         *

# %%
print("ANOVA: Future search intention")

df <- df %>%
  mutate(
    Tri = factor(Tri),
    Sce = factor(Sce)
  )

anova_results <- ezANOVA(
  data      = df,
  dv        = future_search_intention,
  wid       = Tri,
  within    = Sce,
  detailed  = TRUE,
  type      = 3
)

print(anova_results$ANOVA)
print(anova_results$Mauchly)
print(anova_results$`Sphericity Corrections`)
# Out:
# [1] "ANOVA: Future search intention"
#        Effect DFn DFd        SSn       SSd           F            p p<.05
# 1 (Intercept)   1  29 3050.84444  7.748148 11418.79159 3.317563e-39     *
# 2         Sce   2  58    6.42963 14.755556    12.63655 2.784683e-05     *
#         ges
# 1 0.9926778
# 2 0.2222222
#   Effect         W         p p<.05
# 2    Sce 0.8504702 0.1035684
#   Effect       GGe        p[GG] p[GG]<.05       HFe        p[HF] p[HF]<.05
# 2    Sce 0.8699209 7.546004e-05         * 0.9206706 5.111993e-05         *

# %%
column_pairs <- list(
  c("Same Price", "Disadvantaged Customer"),
  c("Same Price", "Favored Customer"),
  c("Disadvantaged Customer", "Favored Customer")
)

df_by_sce <- split(df, df$Sce)

for (metric in c("price_fairness", "purchase_intention", "future_search_intention")) {
    cat("Metric:", metric, "\n")
    
    for (pair in column_pairs) {
        # Assign column names for clarity
        col1 <- pair[1]
        col2 <- pair[2]

        v1 <- df_by_sce[[col1]][[metric]]
        v2 <- df_by_sce[[col2]][[metric]]
        
        # Compute the element-wise difference and then the mean difference
        diff <- v1 - v2
        mean_diff <- mean(diff)
        
        # Perform a paired t-test to assess the significance of the mean difference
        test_result <- t.test(v1, v2, paired = TRUE)
        
        # Print the results
        cat("Comparison: ", col1, "vs", col2, "\n")
        cat("Mean Difference (", col1, " - ", col2, "): ", mean_diff, "\n", sep = "")
        print(test_result)
    }
    cat("\n----------------------------\n")
}
# Out:
# Metric: price_fairness
# Comparison:  Same Price vs Disadvantaged Customer
# Mean Difference (Same Price - Disadvantaged Customer): 0.4333333
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 2.6441, df = 29, p-value = 0.01308
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  0.09815122 0.76851545
# sample estimates:
# mean difference
#       0.4333333
#
# Comparison:  Same Price vs Favored Customer
# Mean Difference (Same Price - Favored Customer): 0.8555556
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 5.5307, df = 29, p-value = 5.81e-06
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  0.5391768 1.1719343
# sample estimates:
# mean difference
#       0.8555556
#
# Comparison:  Disadvantaged Customer vs Favored Customer
# Mean Difference (Disadvantaged Customer - Favored Customer): 0.4222222
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 2.9366, df = 29, p-value = 0.006438
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  0.1281595 0.7162849
# sample estimates:
# mean difference
#       0.4222222
#
#
# ----------------------------
# Metric: purchase_intention
# Comparison:  Same Price vs Disadvantaged Customer
# Mean Difference (Same Price - Disadvantaged Customer): 1.055556
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 4.6692, df = 29, p-value = 6.357e-05
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  0.5931941 1.5179170
# sample estimates:
# mean difference
#        1.055556
#
# Comparison:  Same Price vs Favored Customer
# Mean Difference (Same Price - Favored Customer): 1.4
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 7.5281, df = 29, p-value = 2.682e-08
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  1.019648 1.780352
# sample estimates:
# mean difference
#             1.4
#
# Comparison:  Disadvantaged Customer vs Favored Customer
# Mean Difference (Disadvantaged Customer - Favored Customer): 0.3444444
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 1.6908, df = 29, p-value = 0.1016
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -0.0722144  0.7611033
# sample estimates:
# mean difference
#       0.3444444
#
#
# ----------------------------
# Metric: future_search_intention
# Comparison:  Same Price vs Disadvantaged Customer
# Mean Difference (Same Price - Disadvantaged Customer): -0.5777778
#
# 	Paired t-test
#
# data:  v1 and v2
# t = -4.4863, df = 29, p-value = 0.0001054
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -0.8411743 -0.3143813
# sample estimates:
# mean difference
#      -0.5777778
#
# Comparison:  Same Price vs Favored Customer
# Mean Difference (Same Price - Favored Customer): -0.5555556
#
# 	Paired t-test
#
# data:  v1 and v2
# t = -3.6778, df = 29, p-value = 0.0009522
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -0.8645018 -0.2466093
# sample estimates:
# mean difference
#      -0.5555556
#
# Comparison:  Disadvantaged Customer vs Favored Customer
# Mean Difference (Disadvantaged Customer - Favored Customer): 0.02222222
#
# 	Paired t-test
#
# data:  v1 and v2
# t = 0.20743, df = 29, p-value = 0.8371
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -0.1968869  0.2413314
# sample estimates:
# mean difference
#      0.02222222
#
#
# ----------------------------
