# %%
source("analysis/process/process.R")
# Out:
# ********************* PROCESS for R Version 4.3.1 *********************
#
#            Written by Andrew F. Hayes, Ph.D.  www.afhayes.com
#    Documentation available in Hayes (2022). www.guilford.com/p/hayes3
#
# ***********************************************************************
#
# PROCESS is now ready for use.
# Copyright 2020-2023 by Andrew F. Hayes ALL RIGHTS RESERVED
# Workshop schedule at http://haskayne.ucalgary.ca/CCRAM

# %%
raw_df <- read.csv("results/pilot5_survey1_normal.csv", check.names = FALSE)

# %%
short_col_df <- raw_df
names(short_col_df) <- substr(names(raw_df), 1, 3)

# Print the resulting data frame
short_col_df
# Out:
#    Tri Sce                       001             002
# 1  NA                            00 Demographics 00 Demographics
# 2   0  01 Disadvantaged Customer b               62
# 3   1  01 Same Price             b               62
# 4   2  01 Same Price             b               52
# 5   3  01 Disadvantaged Customer b               32
# 6   4  01 Favored Customer       b               42
# 7   5  01 Same Price             a               42
# 8   6  01 Same Price             b               48
# 9   7  01 Same Price             a               43
# 10  8  01 Disadvantaged Customer b               62
# 11  9  01 Same Price             b               53
# 12 10  01 Disadvantaged Customer a               68
# 13 11  01 Favored Customer       a               32
# 14 12  01 Disadvantaged Customer b               55
# 15 13  01 Same Price             b               62
# 16 14  01 Disadvantaged Customer b               42
#    003             004             005
# 1  00 Demographics 00 Demographics 00 Demographics
# 2  e               a               d
# 3  a               e               d
# 4  c               b               d
# 5  d               a               e
# 6  c               e               d)
# 7  f               a               d
# 8  d               c               d
# 9  e               f               d
# 10 c               a               e
# 11 a \nd           c               c
# 12 e               a               e
# 13 e               a               e
# 14 c               g               e
# 15 a               c               e
# 16 f               a               d
#    006
# 1  01 Distributive Price Fairness Perception
# 2  6
# 3  4
# 4  6
# 5  5
# 6  6
# 7  4
# 8  5
# 9  5
# 10 6
# 11 5
# 12 4
# 13 5
# 14 5
# 15 5
# 16 4
#    007
# 1  01 Distributive Price Fairness Perception
# 2  4
# 3  6
# 4  5
# 5  4
# 6  4
# 7  6
# 8  3
# 9  4
# 10 4
# 11 6
# 12 5
# 13 6
# 14 4
# 15 4
# 16 3
#    008                                       ⋯
# 1  01 Distributive Price Fairness Perception ⋯
# 2  3                                         ⋯
# 3  5                                         ⋯
# 4  4                                         ⋯
# 5  3                                         ⋯
# 6  3                                         ⋯
# 7  5                                         ⋯
# 8  6                                         ⋯
# 9  6                                         ⋯
# 10 5                                         ⋯
# 11 4                                         ⋯
# 12 6                                         ⋯
# 13 4                                         ⋯
# 14 6                                         ⋯
# 15 6                                         ⋯
# 16 6                                         ⋯
#    029                                  030
# 1  18 Perceived Information Sensitivity 18 Perceived Information Sensitivity
# 2  4                                    2
# 3  4                                    3
# 4  4                                    5
# 5  6                                    4
# 6  6                                    3
# 7  7                                    4
# 8  6                                    3
# 9  3                                    2
# 10 6                                    2
# 11 6                                    4
# 12 6                                    4
# 13 4                                    2
# 14 4                                    3
# 15 6                                    3
# 16 5                                    4
#    031                                  032
# 1  18 Perceived Information Sensitivity 18 Perceived Information Sensitivity
# 2  6                                    5
# 3  6                                    4
# 4  6                                    5
# 5  6                                    5
# 6  6                                    5
# 7  6                                    5
# 8  5                                    4
# 9  4                                    6
# 10 4                                    5
# 11 6                                    7
# 12 6                                    5
# 13 6                                    5
# 14 6                                    5
# 15 6                                    4
# 16 6                                    6
#    033                                  034
# 1  18 Perceived Information Sensitivity 19 Willingness to Reveal Information
# 2  3                                    5
# 3  3                                    5
# 4  3                                    4
# 5  3                                    6
# 6  4                                    3
# 7  3                                    2
# 8  3                                    2
# 9  5                                    3
# 10 3                                    4
# 11 5                                    3
# 12 4                                    3
# 13 3                                    6
# 14 2                                    6
# 15 5                                    4
# 16 5                                    2
#    035                                  036
# 1  19 Willingness to Reveal Information 19 Willingness to Reveal Information
# 2  4                                    6
# 3  4                                    5
# 4  5                                    3
# 5  5                                    4
# 6  2                                    4
# 7  3                                    4
# 8  4                                    3
# 9  2                                    4
# 10 3                                    4
# 11 2                                    4
# 12 2                                    4
# 13 4                                    5
# 14 4                                    3
# 15 3                                    5
# 16 4                                    3
#    037                                  038
# 1  19 Willingness to Reveal Information 19 Willingness to Reveal Information
# 2  4                                    2
# 3  6                                    4
# 4  4                                    2
# 5  5                                    3
# 6  3                                    2
# 7  5                                    2
# 8  5                                    2
# 9  6                                    3
# 10 5                                    2
# 11 6                                    3
# 12 5                                    3
# 13 6                                    4
# 14 5                                    3
# 15 6                                    4
# 16 4                                    3

# %%
df <- short_col_df[-1, ]

to_number_if_number <- function(s) {
  if (grepl("^[0-9]+$", s)) {
    as.integer(s)
  } else {
    s
  }
}

for (i in 1:28) {
  col_name <- sprintf("%03d", i)
  df[[col_name]] <- sapply(df[[col_name]], function(x) {
    val <- sub("^([a-zA-Z0-9]+).*", "\\1", x)
    to_number_if_number(val)
  })
}

df$Sce <- sub("^[0-9]*\\s?(.*)$", "\\1", df$Sce)
df
# Out:
#    Tri Sce                    001 002 003 004 005 006 007 008 ⋯ 029 030 031 032
# 2   0  Disadvantaged Customer b   62  e   a   d   6   4   3   ⋯ 4   2   6   5
# 3   1  Same Price             b   62  a   e   d   4   6   5   ⋯ 4   3   6   4
# 4   2  Same Price             b   52  c   b   d   6   5   4   ⋯ 4   5   6   5
# 5   3  Disadvantaged Customer b   32  d   a   e   5   4   3   ⋯ 6   4   6   5
# 6   4  Favored Customer       b   42  c   e   d   6   4   3   ⋯ 6   3   6   5
# 7   5  Same Price             a   42  f   a   d   4   6   5   ⋯ 7   4   6   5
# 8   6  Same Price             b   48  d   c   d   5   3   6   ⋯ 6   3   5   4
# 9   7  Same Price             a   43  e   f   d   5   4   6   ⋯ 3   2   4   6
# 10  8  Disadvantaged Customer b   62  c   a   e   6   4   5   ⋯ 6   2   4   5
# 11  9  Same Price             b   53  a   c   c   5   6   4   ⋯ 6   4   6   7
# 12 10  Disadvantaged Customer a   68  e   a   e   4   5   6   ⋯ 6   4   6   5
# 13 11  Favored Customer       a   32  e   a   e   5   6   4   ⋯ 4   2   6   5
# 14 12  Disadvantaged Customer b   55  c   g   e   5   4   6   ⋯ 4   3   6   5
# 15 13  Same Price             b   62  a   c   e   5   4   6   ⋯ 6   3   6   4
# 16 14  Disadvantaged Customer b   42  f   a   d   4   3   6   ⋯ 5   4   6   6
#    033 034 035 036 037 038
# 2  3   5   4   6   4   2
# 3  3   5   4   5   6   4
# 4  3   4   5   3   4   2
# 5  3   6   5   4   5   3
# 6  4   3   2   4   3   2
# 7  3   2   3   4   5   2
# 8  3   2   4   3   5   2
# 9  5   3   2   4   6   3
# 10 3   4   3   4   5   2
# 11 5   3   2   4   6   3
# 12 4   3   2   4   5   3
# 13 3   6   4   5   6   4
# 14 2   6   4   3   5   3
# 15 5   4   3   5   6   4
# 16 5   2   4   3   4   3

# %%
first_row <- as.data.frame(t(short_col_df[1, , drop = FALSE]), stringsAsFactors = FALSE)
colnames(first_row) <- "groups"

column_group_index <- function(group_name) {
  matching <- first_row$groups == group_name
  cols = rownames(first_row)[matching]
  valid_cols <- intersect(cols, names(df))
  return(valid_cols)
}

result <- column_group_index("01 Distributive Price Fairness Perception")
print(result)
# Out:
# [1] "006" "007" "008"

# %%
df$price_fairness <- rowMeans(sapply(column_group_index("01 Distributive Price Fairness Perception"), function(col) as.integer(df[[col]])))
df$purchase_intention <- rowMeans(sapply(column_group_index("03 Purchase Intention"), function(col) as.integer(df[[col]])))
df$future_search_intention <- rowMeans(sapply(column_group_index("04 Future Search Intention"), function(col) as.integer(df[[col]])))
df$product_involvement <- rowMeans(sapply(column_group_index("08 Product Involvement"), function(col) as.integer(df[[col]])))

df
# Out:
#    Tri Sce                    001 002 003 004 005 006 007 008 ⋯ 033 034 035 036
# 2   0  Disadvantaged Customer b   62  e   a   d   6   4   3   ⋯ 3   5   4   6
# 3   1  Same Price             b   62  a   e   d   4   6   5   ⋯ 3   5   4   5
# 4   2  Same Price             b   52  c   b   d   6   5   4   ⋯ 3   4   5   3
# 5   3  Disadvantaged Customer b   32  d   a   e   5   4   3   ⋯ 3   6   5   4
# 6   4  Favored Customer       b   42  c   e   d   6   4   3   ⋯ 4   3   2   4
# 7   5  Same Price             a   42  f   a   d   4   6   5   ⋯ 3   2   3   4
# 8   6  Same Price             b   48  d   c   d   5   3   6   ⋯ 3   2   4   3
# 9   7  Same Price             a   43  e   f   d   5   4   6   ⋯ 5   3   2   4
# 10  8  Disadvantaged Customer b   62  c   a   e   6   4   5   ⋯ 3   4   3   4
# 11  9  Same Price             b   53  a   c   c   5   6   4   ⋯ 5   3   2   4
# 12 10  Disadvantaged Customer a   68  e   a   e   4   5   6   ⋯ 4   3   2   4
# 13 11  Favored Customer       a   32  e   a   e   5   6   4   ⋯ 3   6   4   5
# 14 12  Disadvantaged Customer b   55  c   g   e   5   4   6   ⋯ 2   6   4   3
# 15 13  Same Price             b   62  a   c   e   5   4   6   ⋯ 5   4   3   5
# 16 14  Disadvantaged Customer b   42  f   a   d   4   3   6   ⋯ 5   2   4   3
#    037 038 price_fairness purchase_intention future_search_intention
# 2  4   2   4.333333       5.666667           6.000000
# 3  6   4   5.000000       6.666667           5.000000
# 4  4   2   5.000000       6.666667           5.666667
# 5  5   3   4.000000       5.666667           5.666667
# 6  3   2   4.333333       5.666667           5.666667
# 7  5   2   5.000000       6.333333           4.666667
# 8  5   2   4.666667       6.333333           5.000000
# 9  6   3   5.000000       6.666667           5.333333
# 10 5   2   5.000000       6.333333           6.333333
# 11 6   3   5.000000       6.666667           5.666667
# 12 5   3   5.000000       5.000000           6.000000
# 13 6   4   5.000000       6.000000           5.000000
# 14 5   3   5.000000       5.000000           6.333333
# 15 6   4   5.000000       6.666667           4.666667
# 16 4   3   4.333333       5.333333           6.000000
#    product_involvement
# 2  5.571429
# 3  5.714286
# 4  5.285714
# 5  5.142857
# 6  5.285714
# 7  5.714286
# 8  5.285714
# 9  5.428571
# 10 5.571429
# 11 5.428571
# 12 5.571429
# 13 5.000000
# 14 4.857143
# 15 6.285714
# 16 5.428571

# %%
variablen <- c("price_fairness", "purchase_intention", "future_search_intention", "product_involvement")
n <- length(variablen)

cor_matrix <- matrix("", nrow = n, ncol = n, dimnames = list(variablen, variablen))
p_values <- matrix(NA, nrow = n, ncol = n, dimnames = list(variablen, variablen))

for (i in seq_along(variablen)) {
  for (j in seq_along(variablen)) {
    if (i == j) {
      cor_matrix[i, j] <- "1.000"
    } else {
      test <- cor.test(df[[variablen[i]]], df[[variablen[j]]])
      r <- test$estimate
      p <- test$p.value
      stars <- if (p < 0.01) {
        "***"
      } else if (p < 0.05) {
        "**"
      } else if (p < 0.10) {
        "*"
      } else {
        ""
      }
      cor_matrix[i, j] <- sprintf("%.3f%s", r, stars)
      p_values[i, j] <- p
    }
  }
}

means <- round(colMeans(df[variablen], na.rm = TRUE), 2)
stds <- round(apply(df[variablen], 2, sd, na.rm = TRUE), 2)

cor_matrix <- rbind(cor_matrix, Mean = as.character(means), `Standard Deviation` = as.character(stds))
cor_matrix
# Out:
#                         price_fairness purchase_intention
# price_fairness          1.000          0.419
# purchase_intention      0.419          1.000
# future_search_intention -0.243         -0.603**
# product_involvement     0.220          0.438
# Mean                    4.78           6.04
# Standard Deviation      0.35           0.62
#                         future_search_intention product_involvement
# price_fairness          -0.243                  0.220
# purchase_intention      -0.603**                0.438
# future_search_intention 1.000                   -0.422
# product_involvement     -0.422                  1.000
# Mean                    5.53                    5.44
# Standard Deviation      0.56                    0.34

# %%
library(psych)

categories <- c("01 Distributive Price Fairness Perception",
                "03 Purchase Intention",
                "04 Future Search Intention",
                "08 Product Involvement")

for (cat in categories) {
  cols <- column_group_index(cat)
  if (length(valid_cols) == 0) next
  items <- df[, valid_cols, drop = FALSE]
  alpha_val <- psych::alpha(items)$total$raw_alpha
  print(paste(cat, ":", alpha_val))
}
# Out:
# Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# “NAs introduced by coercion”
# Warning message in psych::alpha(items):
# “Item = 025 had no variance and was deleted but still is counted in the score”
# Warning message in min((max.item - min.item) > max):
# “no non-missing arguments to min; returning Inf”
# Number of categories should be increased  in order to count frequencies.
# Error in cov(x, use = use): 'x' is empty
# Traceback:
#
# 1. cov(x, use = use)
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "'x' is empty", base::quote(cov(x, use = use)))

# %%
df$age <- df[["002"]]
df$gender <- df[["001"]]
df$dummy_gender <- as.integer(df$gender == "b")
df$income <- df[["005"]]
df$dummy_income <- as.integer(df$income %in% c("d", "e", "f"))
df$frequency <- df[[column_group_index("12 Frequency of Online Purchases")[1]]]
df$dummy_frequency <- as.integer(df$frequency == "f")
df$favored <- as.integer(df$Sce == "Favored Customer")
df$disadvantaged <- as.integer(df$Sce == "Disadvantaged Customer")
df$scenario <- ifelse(df$Sce == "Favored Customer", 1,
               ifelse(df$Sce == "Disadvantaged Customer", 2, 0))
df$education = df[["003"]]
df$employment = df[["004"]]
df$social_media_usage = df[[column_group_index("14 Social Media Usage")[1]]]

df$internet_usage = df[[column_group_index("11 Daily Internet Usage")[1]]]
df$money_spent = df[[column_group_index("13 Money Spent for Online Purchases")[1]]]

df
# Out:
#    Tri Sce                    001 002 003 004 005 006 007 008 ⋯ frequency
# 2   0  Disadvantaged Customer b   62  e   a   d   6   4   3   ⋯ f
# 3   1  Same Price             b   62  a   e   d   4   6   5   ⋯ f
# 4   2  Same Price             b   52  c   b   d   6   5   4   ⋯ c
# 5   3  Disadvantaged Customer b   32  d   a   e   5   4   3   ⋯ f
# 6   4  Favored Customer       b   42  c   e   d   6   4   3   ⋯ f
# 7   5  Same Price             a   42  f   a   d   4   6   5   ⋯ f
# 8   6  Same Price             b   48  d   c   d   5   3   6   ⋯ f
# 9   7  Same Price             a   43  e   f   d   5   4   6   ⋯ f
# 10  8  Disadvantaged Customer b   62  c   a   e   6   4   5   ⋯ f
# 11  9  Same Price             b   53  a   c   c   5   6   4   ⋯ f
# 12 10  Disadvantaged Customer a   68  e   a   e   4   5   6   ⋯ f
# 13 11  Favored Customer       a   32  e   a   e   5   6   4   ⋯ e
# 14 12  Disadvantaged Customer b   55  c   g   e   5   4   6   ⋯ d
# 15 13  Same Price             b   62  a   c   e   5   4   6   ⋯ f
# 16 14  Disadvantaged Customer b   42  f   a   d   4   3   6   ⋯ c
#    dummy_frequency favored disadvantaged scenario education employment
# 2  1               0       1             2        e         a
# 3  1               0       0             0        a         e
# 4  0               0       0             0        c         b
# 5  1               0       1             2        d         a
# 6  1               1       0             1        c         e
# 7  1               0       0             0        f         a
# 8  1               0       0             0        d         c
# 9  1               0       0             0        e         f
# 10 1               0       1             2        c         a
# 11 1               0       0             0        a         c
# 12 1               0       1             2        e         a
# 13 0               1       0             1        e         a
# 14 0               0       1             2        c         g
# 15 1               0       0             0        a         c
# 16 0               0       1             2        f         a
#    social_media_usage internet_usage money_spent
# 2  a                  e              e
# 3  a                  c              f
# 4  a                  d              g
# 5  a                  c              g
# 6  a                  c              f
# 7  a                  c              g
# 8  b                  c              f
# 9  a                  d              g
# 10 a                  d              g
# 11 a                  c              e
# 12 a                  e              f
# 13 b                  e              e
# 14 b                  d              g
# 15 a                  e              f
# 16 a                  c              f

# %%
process(data = df,
        model = 4,
        y = "purchase_intention", 
        x = "scenario",
        mcx = 1,
        m = "price_fairness",
        cov = c("age", "dummy_gender", "dummy_income", "dummy_frequency"),
        boot = 100,
        seed = 654321)
# Out:
# ********************* PROCESS for R Version 4.3.1 *********************
#
#            Written by Andrew F. Hayes, Ph.D.  www.afhayes.com
#    Documentation available in Hayes (2022). www.guilford.com/p/hayes3
#
# ***********************************************************************
#
# Model : 4
#     Y : purchase_intention
#     X : scenario
#     M : price_fairness
#
# Covariates:
#        age dummy_gender dummy_income dummy_frequency
#
# Sample size: 15
#
# Custom seed: 654321
#
# Coding of categorical X variable for analysis:
#    scenario        X1        X2
#      0.0000    0.0000    0.0000
#      1.0000    1.0000    0.0000
#      2.0000    0.0000    1.0000
#
# ***********************************************************************
# Outcome Variable: price_fairness
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.8917    0.7952    0.0436    5.1763    6.0000    8.0000    0.0185
#
# Model:
#                     coeff        se         t         p      LLCI      ULCI
# constant           4.6090    0.3790   12.1608    0.0000    3.7346    5.4834
# X1                -0.1476    0.1907   -0.7737    0.4614   -0.5876    0.2925
# X2                -0.3634    0.1248   -2.9109    0.0196   -0.6514   -0.0754
# age                0.0211    0.0058    3.6218    0.0068    0.0077    0.0345
# dummy_gender      -0.4002    0.1298   -3.0834    0.0150   -0.6997   -0.1008
# dummy_income      -0.2119    0.2309   -0.9176    0.3856   -0.7445    0.3208
# dummy_frequency   -0.3273    0.1323   -2.4732    0.0385   -0.6325   -0.0220
#
# ***********************************************************************
# Outcome Variable: purchase_intention
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.8909    0.7938    0.1562    3.8494    7.0000    7.0000    0.0481
#
# Model:
#                     coeff        se         t         p      LLCI      ULCI
# constant           2.5541    3.1663    0.8066    0.4464   -4.9378   10.0460
# X1                -0.5383    0.3743   -1.4384    0.1935   -1.4238    0.3472
# X2                -0.7506    0.3390   -2.2140    0.0624   -1.5527    0.0516
# price_fairness     0.8368    0.6691    1.2506    0.2513   -0.7464    2.4200
# age               -0.0194    0.0179   -1.0844    0.3141   -0.0618    0.0230
# dummy_gender       0.5176    0.3634    1.4244    0.1973   -0.3422    1.3775
# dummy_income       0.1522    0.4593    0.3314    0.7500   -0.9346    1.2391
# dummy_frequency    0.4407    0.3327    1.3249    0.2268   -0.3464    1.2278
#
# ***********************************************************************
# Bootstrapping progress:
#   |>                                                             |   1%
# Error in solve.default(t(x) %*% x): Lapack routine dgesv: system is exactly singular: U[2,2] = 0
# Traceback:
#
# 1. process.modelest(y, x, type = 1, full = 0, xp2, hc)
# 2. solve(t(x) %*% x)
# 3. solve.default(t(x) %*% x)
# 4. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "Lapack routine dgesv: system is exactly singular: U[2,2] = 0",
#  .     base::quote(solve.default(t(x) %*% x)))

# %%
process(data = df,
        model = 4,
        y = "future_search_intention", 
        x = "scenario",
        mcx = 1,
        m = "price_fairness",
        cov = c("age", "dummy_gender", "dummy_income", "dummy_frequency"),
        boot = 100,
        seed = 654321)
# Out:
# ********************* PROCESS for R Version 4.3.1 *********************
#
#            Written by Andrew F. Hayes, Ph.D.  www.afhayes.com
#    Documentation available in Hayes (2022). www.guilford.com/p/hayes3
#
# ***********************************************************************
#
# Model : 4
#     Y : future_search_intention
#     X : scenario
#     M : price_fairness
#
# Covariates:
#        age dummy_gender dummy_income dummy_frequency
#
# Sample size: 15
#
# Custom seed: 654321
#
# Coding of categorical X variable for analysis:
#    scenario        X1        X2
#      0.0000    0.0000    0.0000
#      1.0000    1.0000    0.0000
#      2.0000    0.0000    1.0000
#
# ***********************************************************************
# Outcome Variable: price_fairness
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.8917    0.7952    0.0436    5.1763    6.0000    8.0000    0.0185
#
# Model:
#                     coeff        se         t         p      LLCI      ULCI
# constant           4.6090    0.3790   12.1608    0.0000    3.7346    5.4834
# X1                -0.1476    0.1907   -0.7737    0.4614   -0.5876    0.2925
# X2                -0.3634    0.1248   -2.9109    0.0196   -0.6514   -0.0754
# age                0.0211    0.0058    3.6218    0.0068    0.0077    0.0345
# dummy_gender      -0.4002    0.1298   -3.0834    0.0150   -0.6997   -0.1008
# dummy_income      -0.2119    0.2309   -0.9176    0.3856   -0.7445    0.3208
# dummy_frequency   -0.3273    0.1323   -2.4732    0.0385   -0.6325   -0.0220
#
# ***********************************************************************
# Outcome Variable: future_search_intention
#
# Model Summary:
#           R      R-sq       MSE         F       df1       df2         p
#      0.8797    0.7739    0.1422    3.4219    7.0000    7.0000    0.0634
#
# Model:
#                     coeff        se         t         p      LLCI      ULCI
# constant           4.4154    3.0202    1.4620    0.1871   -2.7307   11.5616
# X1                 0.3881    0.3570    1.0872    0.3130   -0.4565    1.2328
# X2                 0.9853    0.3234    3.0470    0.0187    0.2202    1.7505
# price_fairness     0.1823    0.6382    0.2856    0.7835   -1.3279    1.6924
# age                0.0055    0.0171    0.3241    0.7553   -0.0349    0.0460
# dummy_gender       0.2162    0.3466    0.6237    0.5526   -0.6040    1.0363
# dummy_income      -0.5489    0.4381   -1.2529    0.2505   -1.5856    0.4878
# dummy_frequency   -0.1699    0.3173   -0.5355    0.6089   -0.9207    0.5809
#
# ***********************************************************************
# Bootstrapping progress:
#   |>                                                             |   1%
# Error in solve.default(t(x) %*% x): Lapack routine dgesv: system is exactly singular: U[2,2] = 0
# Traceback:
#
# 1. process.modelest(y, x, type = 1, full = 0, xp2, hc)
# 2. solve(t(x) %*% x)
# 3. solve.default(t(x) %*% x)
# 4. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "Lapack routine dgesv: system is exactly singular: U[2,2] = 0",
#  .     base::quote(solve.default(t(x) %*% x)))

# %%
cat_list <- c("00 Demographics", 
              "11 Daily Internet Usage", 
              "12 Frequency of Online Purchases", 
              "13 Money Spent for Online Purchases", 
              "14 Social Media Usage")

freq_table <- data.frame()

for (cat in cat_list) {
  cols <- column_group_index(cat)
  valid_cols <- intersect(cols, names(df))
  if (length(valid_cols) == 0) next
  for (col in valid_cols) {
    tbl <- table(df[[col]], useNA = "ifany")
    total <- sum(tbl)
    tmp <- data.frame(
      "Question" = cat,
      "Column"   = col,
      "Response" = names(tbl),
      "Absolute frequency" = as.numeric(tbl),
      "Relative frequency (in %)" = round(100 * as.numeric(tbl) / total, 2),
      check.names = FALSE,
      stringsAsFactors = FALSE
    )
    freq_table <- rbind(freq_table, tmp)
  }
}

freq_table
# Out:
#    Question                            Column Response Absolute frequency
# 1  00 Demographics                     001    a         4
# 2  00 Demographics                     001    b        11
# 3  00 Demographics                     002    32        2
# 4  00 Demographics                     002    42        3
# 5  00 Demographics                     002    43        1
# 6  00 Demographics                     002    48        1
# 7  00 Demographics                     002    52        1
# 8  00 Demographics                     002    53        1
# 9  00 Demographics                     002    55        1
# 10 00 Demographics                     002    62        4
# 11 00 Demographics                     002    68        1
# 12 00 Demographics                     003    a         3
# 13 00 Demographics                     003    c         4
# 14 00 Demographics                     003    d         2
# 15 00 Demographics                     003    e         4
# 16 00 Demographics                     003    f         2
# 17 00 Demographics                     004    a         7
# 18 00 Demographics                     004    b         1
# 19 00 Demographics                     004    c         3
# 20 00 Demographics                     004    e         2
# 21 00 Demographics                     004    f         1
# 22 00 Demographics                     004    g         1
# 23 00 Demographics                     005    c         1
# 24 00 Demographics                     005    d         8
# 25 00 Demographics                     005    e         6
# 26 11 Daily Internet Usage             022    c         7
# 27 11 Daily Internet Usage             022    d         4
# 28 11 Daily Internet Usage             022    e         4
# 29 12 Frequency of Online Purchases    023    c         2
# 30 12 Frequency of Online Purchases    023    d         1
# 31 12 Frequency of Online Purchases    023    e         1
# 32 12 Frequency of Online Purchases    023    f        11
# 33 13 Money Spent for Online Purchases 024    e         3
# 34 13 Money Spent for Online Purchases 024    f         6
# 35 13 Money Spent for Online Purchases 024    g         6
# 36 14 Social Media Usage               025    a        12
# 37 14 Social Media Usage               025    b         3
#    Relative frequency (in %)
# 1  26.67
# 2  73.33
# 3  13.33
# 4  20.00
# 5   6.67
# 6   6.67
# 7   6.67
# 8   6.67
# 9   6.67
# 10 26.67
# 11  6.67
# 12 20.00
# 13 26.67
# 14 13.33
# 15 26.67
# 16 13.33
# 17 46.67
# 18  6.67
# 19 20.00
# 20 13.33
# 21  6.67
# 22  6.67
# 23  6.67
# 24 53.33
# 25 40.00
# 26 46.67
# 27 26.67
# 28 26.67
# 29 13.33
# 30  6.67
# 31  6.67
# 32 73.33
# 33 20.00
# 34 40.00
# 35 40.00
# 36 80.00
# 37 20.00

# %%
library(dplyr)

cat <- "17 Realism Check"
cols <- column_group_index(cat)

for (col in cols) {
  cat("ANOVA for:", col, "\n\n")
  
  # Descriptive statistics
  summary_df <- df %>%
    group_by(Sce) %>%
    summarize(
      M  = round(mean(.data[[col]], na.rm = TRUE), 2),
      SD = round(sd(.data[[col]], na.rm = TRUE), 2),
      n  = n()
    )
  print(summary_df)
  
  # One-way ANOVA
  fit <- aov(df[[col]] ~ Sce, data = df)
  print(summary(fit))
  
  cat("\n----------------------------------------\n\n")
}
# Out:
# ANOVA for: 027
#
# # A tibble: 3 × 4
#   Sce                        M    SD     n
#   <chr>                  <dbl> <dbl> <int>
# 1 Disadvantaged Customer  5     1.1      6
# 2 Favored Customer        5.5   0.71     2
# 3 Same Price              6.14  0.38     7
#             Df Sum Sq Mean Sq F value Pr(>F)
# Sce          2  4.243  2.1214    3.46 0.0651 .
# Residuals   12  7.357  0.6131
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ----------------------------------------
#
# ANOVA for: 028
#
# # A tibble: 3 × 4
#   Sce                        M    SD     n
#   <chr>                  <dbl> <dbl> <int>
# 1 Disadvantaged Customer  6.5   0.84     6
# 2 Favored Customer        6.5   0.71     2
# 3 Same Price              6.29  1.11     7
#             Df Sum Sq Mean Sq F value Pr(>F)
# Sce          2  0.171  0.0857    0.09  0.915
# Residuals   12 11.429  0.9524
#
# ----------------------------------------

# %%
df
# Out:
#    Tri Sce                    001 002 003 004 005 006 007 008 ⋯ income
# 2   0  Disadvantaged Customer b   62  e   a   d   6   4   3   ⋯ d
# 3   1  Same Price             b   62  a   e   d   4   6   5   ⋯ d
# 4   2  Same Price             b   52  c   b   d   6   5   4   ⋯ d
# 5   3  Disadvantaged Customer b   32  d   a   e   5   4   3   ⋯ e
# 6   4  Favored Customer       b   42  c   e   d   6   4   3   ⋯ d
# 7   5  Same Price             a   42  f   a   d   4   6   5   ⋯ d
# 8   6  Same Price             b   48  d   c   d   5   3   6   ⋯ d
# 9   7  Same Price             a   43  e   f   d   5   4   6   ⋯ d
# 10  8  Disadvantaged Customer b   62  c   a   e   6   4   5   ⋯ e
# 11  9  Same Price             b   53  a   c   c   5   6   4   ⋯ c
# 12 10  Disadvantaged Customer a   68  e   a   e   4   5   6   ⋯ e
# 13 11  Favored Customer       a   32  e   a   e   5   6   4   ⋯ e
# 14 12  Disadvantaged Customer b   55  c   g   e   5   4   6   ⋯ e
# 15 13  Same Price             b   62  a   c   e   5   4   6   ⋯ e
# 16 14  Disadvantaged Customer b   42  f   a   d   4   3   6   ⋯ d
#    dummy_income frequency dummy_frequency favored disadvantaged scenario
# 2  1            f         1               0       1             2
# 3  1            f         1               0       0             0
# 4  1            c         0               0       0             0
# 5  1            f         1               0       1             2
# 6  1            f         1               1       0             1
# 7  1            f         1               0       0             0
# 8  1            f         1               0       0             0
# 9  1            f         1               0       0             0
# 10 1            f         1               0       1             2
# 11 0            f         1               0       0             0
# 12 1            f         1               0       1             2
# 13 1            e         0               1       0             1
# 14 1            d         0               0       1             2
# 15 1            f         1               0       0             0
# 16 1            c         0               0       1             2
#    education employment social_media_usage
# 2  e         a          a
# 3  a         e          a
# 4  c         b          a
# 5  d         a          a
# 6  c         e          a
# 7  f         a          a
# 8  d         c          b
# 9  e         f          a
# 10 c         a          a
# 11 a         c          a
# 12 e         a          a
# 13 e         a          b
# 14 c         g          b
# 15 a         c          a
# 16 f         a          a

# %%
vars <- c("gender", "education", "employment", "social_media_usage")

for (i in 1:length(vars)) { 
    for (j in 1:i) {
        if (i != j){
            cat("Chi-squared test for", vars[i], "vs", vars[j])
            tab <- table(df[[vars[i]]], df[[vars[j]]])
            print(tab)
            test <- chisq.test(tab)
            print(test)
        }
    }
}
# Out:
# Chi-squared test for education vs gender
#     a b
#   a 0 3
#   c 0 4
#   d 0 2
#   e 3 1
#   f 1 1
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 8.608, df = 4, p-value = 0.07168
#
# Chi-squared test for employment vs gender
#     a b
#   a 3 4
#   b 0 1
#   c 0 3
#   e 0 2
#   f 1 0
#   g 0 1
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 6.2338, df = 5, p-value = 0.2841
#
# Chi-squared test for employment vs education
#     a c d e f
#   a 0 1 1 3 2
#   b 0 1 0 0 0
#   c 2 0 1 0 0
#   e 1 1 0 0 0
#   f 0 0 0 1 0
#   g 0 1 0 0 0
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 20.506, df = 20, p-value = 0.4267
#
# Chi-squared test for social_media_usage vs gender
#     a b
#   a 3 9
#   b 1 2
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test with Yates' continuity correction
#
# data:  tab
# X-squared = 1.1598e-30, df = 1, p-value = 1
#
# Chi-squared test for social_media_usage vs education
#     a c d e f
#   a 3 3 1 3 2
#   b 0 1 1 1 0
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 2.5, df = 4, p-value = 0.6446
#
# Chi-squared test for social_media_usage vs employment
#     a b c e f g
#   a 6 1 2 2 1 0
#   b 1 0 1 0 0 1
# Warning message in chisq.test(tab):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  tab
# X-squared = 5.4762, df = 5, p-value = 0.3606

# %%
vars <- c("product_involvement", "age", "income", "internet_usage", "frequency", "money_spent")

for (var in vars) {
  cat("Kruskal-Wallis test for", var, "vs Sce\n")
  result <- kruskal.test(df[[var]] ~ df$Sce)
  print(result)
  cat("\n--------------------------------\n\n")
}
# Out:
# Kruskal-Wallis test for product_involvement vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 3.2029, df = 2, p-value = 0.2016
#
#
# --------------------------------
#
# Kruskal-Wallis test for age vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 3.3798, df = 2, p-value = 0.1845
#
#
# --------------------------------
#
# Kruskal-Wallis test for income vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 3.9562, df = 2, p-value = 0.1383
#
#
# --------------------------------
#
# Kruskal-Wallis test for internet_usage vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0.87707, df = 2, p-value = 0.645
#
#
# --------------------------------
#
# Kruskal-Wallis test for frequency vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 0.69076, df = 2, p-value = 0.708
#
#
# --------------------------------
#
# Kruskal-Wallis test for money_spent vs Sce
#
# 	Kruskal-Wallis rank sum test
#
# data:  df[[var]] by df$Sce
# Kruskal-Wallis chi-squared = 1.8889, df = 2, p-value = 0.3889
#
#
# --------------------------------
